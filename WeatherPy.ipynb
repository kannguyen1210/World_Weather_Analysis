# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 1 | keetmanshoop
# Processing Record 3 of Set 1 | flinders
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | ust-maya
# Processing Record 7 of Set 1 | arman
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | plettenberg bay
# Processing Record 14 of Set 1 | dunedin
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | pozo colorado
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | victor harbor
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | sur
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | alamos
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | galesburg
# Processing Record 33 of Set 1 | japura
# Processing Record 34 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 | kathmandu
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | noyabrsk
# Processing Record 38 of Set 1 | najran
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | mudyuga
# City not found. Skipping...
# Processing Record 42 of Set 1 | bongor
# Processing Record 43 of Set 1 | hlotse
# Processing Record 44 of Set 1 | san rafael
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | charters towers
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | jalu
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | roma
# Processing Record 3 of Set 2 | aklavik
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | esquias
# Processing Record 6 of Set 2 | saint anthony
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | birjand
# Processing Record 9 of Set 2 | phichit
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | puerto escondido
# Processing Record 13 of Set 2 | luba
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | winnemucca
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | zeya
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | ulagan
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | ahipara
# Processing Record 27 of Set 2 | vila
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | wanning
# Processing Record 30 of Set 2 | buin
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | okhotsk
# Processing Record 33 of Set 2 | deputatskiy
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | kumylzhenskaya
# Processing Record 39 of Set 2 | lompoc
# Processing Record 40 of Set 2 | paamiut
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | perelyub
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 2 | sao gabriel da cachoeira
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | miranda
# Processing Record 2 of Set 3 | praya
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | lodja
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 7 of Set 3 | chengde
# Processing Record 8 of Set 3 | lao cai
# Processing Record 9 of Set 3 | ladario
# Processing Record 10 of Set 3 | namatanai
# Processing Record 11 of Set 3 | pochutla
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | vilyuysk
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | buchanan
# Processing Record 16 of Set 3 | egvekinot
# Processing Record 17 of Set 3 | tooele
# Processing Record 18 of Set 3 | falun
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | waipawa
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | rosetown
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | kavaratti
# Processing Record 31 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 32 of Set 3 | corum
# Processing Record 33 of Set 3 | ahuimanu
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | rabo de peixe
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | coihaique
# Processing Record 38 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | johnstown
# Processing Record 41 of Set 3 | porto torres
# Processing Record 42 of Set 3 | takoradi
# Processing Record 43 of Set 3 | sao felix do xingu
# Processing Record 44 of Set 3 | labuan
# Processing Record 45 of Set 3 | puerto asis
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | northam
# Processing Record 48 of Set 3 | beira
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | nenjiang
# Processing Record 1 of Set 4 | goderich
# Processing Record 2 of Set 4 | olonets
# Processing Record 3 of Set 4 | puerto madero
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | banjar
# Processing Record 6 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 4 | oranjemund
# Processing Record 8 of Set 4 | korgen
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 4 | saldanha
# Processing Record 14 of Set 4 | takab
# Processing Record 15 of Set 4 | ozernovskiy
# Processing Record 16 of Set 4 | samarai
# Processing Record 17 of Set 4 | avera
# Processing Record 18 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | haimen
# Processing Record 21 of Set 4 | thinadhoo
# Processing Record 22 of Set 4 | bathsheba
# Processing Record 23 of Set 4 | susaki
# Processing Record 24 of Set 4 | warrnambool
# Processing Record 25 of Set 4 | axim
# Processing Record 26 of Set 4 | marienburg
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | omboue
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | lynchburg
# Processing Record 33 of Set 4 | imeni poliny osipenko
# Processing Record 34 of Set 4 | henties bay
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | bonavista
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | yar-sale
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | honiara
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | seminole
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | hervey bay
# Processing Record 48 of Set 4 | marsh harbour
# Processing Record 49 of Set 4 | flic en flac
# Processing Record 50 of Set 4 | jiangyou
# Processing Record 1 of Set 5 | gazojak
# Processing Record 2 of Set 5 | luza
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | te anau
# Processing Record 6 of Set 5 | dwarka
# Processing Record 7 of Set 5 | panama city
# Processing Record 8 of Set 5 | rudbar
# Processing Record 9 of Set 5 | calbuco
# Processing Record 10 of Set 5 | jertih
# Processing Record 11 of Set 5 | sorong
# Processing Record 12 of Set 5 | atasu
# Processing Record 13 of Set 5 | pokaran
# Processing Record 14 of Set 5 | davila
# Processing Record 15 of Set 5 | yichang
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | berlevag
# Processing Record 19 of Set 5 | mehamn
# Processing Record 20 of Set 5 | nioro
# Processing Record 21 of Set 5 | akyab
# Processing Record 22 of Set 5 | belmonte
# Processing Record 23 of Set 5 | raudeberg
# Processing Record 24 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | kloulklubed
# Processing Record 27 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 5 | magnor
# Processing Record 29 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 5 | petrolina
# Processing Record 31 of Set 5 | karasjok
# Processing Record 32 of Set 5 | dinhata
# Processing Record 33 of Set 5 | goteborg
# City not found. Skipping...
# Processing Record 34 of Set 5 | gat
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | tautira
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | istmina
# Processing Record 39 of Set 5 | adrar
# Processing Record 40 of Set 5 | farim
# Processing Record 41 of Set 5 | boende
# Processing Record 42 of Set 5 | amapa
# Processing Record 43 of Set 5 | comodoro rivadavia
# Processing Record 44 of Set 5 | kahului
# Processing Record 45 of Set 5 | sarahan
# Processing Record 46 of Set 5 | flin flon
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | aripuana
# Processing Record 49 of Set 5 | silva jardim
# Processing Record 50 of Set 5 | mansa
# Processing Record 1 of Set 6 | lumbog
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | kilemary
# Processing Record 4 of Set 6 | mapiri
# Processing Record 5 of Set 6 | chegdomyn
# Processing Record 6 of Set 6 | porto novo
# Processing Record 7 of Set 6 | wasilla
# Processing Record 8 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 6 | batagay-alyta
# Processing Record 10 of Set 6 | basqal
# Processing Record 11 of Set 6 | notse
# Processing Record 12 of Set 6 | hirara
# Processing Record 13 of Set 6 | sena madureira
# Processing Record 14 of Set 6 | takaka
# Processing Record 15 of Set 6 | montepulciano
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | mineros
# Processing Record 18 of Set 6 | alta
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | raga
# Processing Record 22 of Set 6 | barhiya
# Processing Record 23 of Set 6 | wolgast
# Processing Record 24 of Set 6 | mkushi
# Processing Record 25 of Set 6 | bilibino
# Processing Record 26 of Set 6 | nsanje
# Processing Record 27 of Set 6 | nadadores
# Processing Record 28 of Set 6 | ixtapa
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | yafran
# Processing Record 31 of Set 6 | arteaga
# Processing Record 32 of Set 6 | proletarsk
# Processing Record 33 of Set 6 | lagos
# Processing Record 34 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 6 | buala
# Processing Record 36 of Set 6 | cape elizabeth
# City not found. Skipping...
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | bethal
# Processing Record 39 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | rocha
# Processing Record 42 of Set 6 | holsted
# Processing Record 43 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 6 | podporozhye
# Processing Record 46 of Set 6 | hofn
# Processing Record 47 of Set 6 | ballina
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | kodiak
# Processing Record 50 of Set 6 | hami
# Processing Record 1 of Set 7 | yenagoa
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | sao joao do paraiso
# Processing Record 4 of Set 7 | kirakira
# Processing Record 5 of Set 7 | krasnoselkup
# Processing Record 6 of Set 7 | talnakh
# Processing Record 7 of Set 7 | chiredzi
# Processing Record 8 of Set 7 | maningrida
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | fuerte olimpo
# Processing Record 12 of Set 7 | anadyr
# Processing Record 13 of Set 7 | dikson
# Processing Record 14 of Set 7 | kalmunai
# Processing Record 15 of Set 7 | ossora
# Processing Record 16 of Set 7 | verkhnevilyuysk
# Processing Record 17 of Set 7 | monticello
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | gainesville
# Processing Record 20 of Set 7 | komsomolskiy
# Processing Record 21 of Set 7 | bereda
# Processing Record 22 of Set 7 | noumea
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | timra
# Processing Record 25 of Set 7 | avrille
# Processing Record 26 of Set 7 | guilin
# Processing Record 27 of Set 7 | avarua
# Processing Record 28 of Set 7 | tabou
# Processing Record 29 of Set 7 | zyryanskoye
# Processing Record 30 of Set 7 | garden city
# Processing Record 31 of Set 7 | muros
# Processing Record 32 of Set 7 | turayf
# Processing Record 33 of Set 7 | nome
# Processing Record 34 of Set 7 | kamenka
# Processing Record 35 of Set 7 | bakchar
# Processing Record 36 of Set 7 | parrita
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | pilar
# Processing Record 39 of Set 7 | shirokiy
# Processing Record 40 of Set 7 | guaranesia
# Processing Record 41 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 7 | ipixuna
# Processing Record 43 of Set 7 | lensk
# Processing Record 44 of Set 7 | hasan abdal
# Processing Record 45 of Set 7 | lorengau
# Processing Record 46 of Set 7 | ust-nera
# Processing Record 47 of Set 7 | nanortalik
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | zheleznodorozhnyy
# Processing Record 50 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 8 | sergach
# Processing Record 2 of Set 8 | khatanga
# Processing Record 3 of Set 8 | guanica
# Processing Record 4 of Set 8 | moose factory
# Processing Record 5 of Set 8 | portland
# Processing Record 6 of Set 8 | the valley
# Processing Record 7 of Set 8 | aswan
# Processing Record 8 of Set 8 | bredasdorp
# Processing Record 9 of Set 8 | monteagudo
# Processing Record 10 of Set 8 | boca do acre
# Processing Record 11 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 12 of Set 8 | kholmy
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | general roca
# Processing Record 15 of Set 8 | byadgi
# Processing Record 16 of Set 8 | man
# Processing Record 17 of Set 8 | santa cruz de tenerife
# Processing Record 18 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | ko samui
# Processing Record 21 of Set 8 | hanzhong
# Processing Record 22 of Set 8 | marfino
# Processing Record 23 of Set 8 | tirlyanskiy
# Processing Record 24 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 8 | lakes entrance
# Processing Record 26 of Set 8 | dong hoi
# Processing Record 27 of Set 8 | neyshabur
# Processing Record 28 of Set 8 | phangnga
# Processing Record 29 of Set 8 | kemi
# Processing Record 30 of Set 8 | chalus
# Processing Record 31 of Set 8 | mobaye
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | narasannapeta
# Processing Record 34 of Set 8 | nkhotakota
# Processing Record 35 of Set 8 | zalesovo
# Processing Record 36 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 8 | port hedland
# Processing Record 38 of Set 8 | ribeira grande
# Processing Record 39 of Set 8 | qasigiannguit
# Processing Record 40 of Set 8 | safita
# Processing Record 41 of Set 8 | mahajanga
# Processing Record 42 of Set 8 | teahupoo
# Processing Record 43 of Set 8 | longyearbyen
# Processing Record 44 of Set 8 | port elizabeth
# Processing Record 45 of Set 8 | sao jose da coroa grande
# Processing Record 46 of Set 8 | goure
# Processing Record 47 of Set 8 | kingman
# Processing Record 48 of Set 8 | coahuayana
# Processing Record 49 of Set 8 | tottori
# Processing Record 50 of Set 8 | bilma
# Processing Record 1 of Set 9 | turbat
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 9 | jacareacanga
# Processing Record 5 of Set 9 | puerto parra
# Processing Record 6 of Set 9 | bucerias
# Processing Record 7 of Set 9 | fougamou
# Processing Record 8 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 9 of Set 9 | hermosillo
# Processing Record 10 of Set 9 | canon city
# Processing Record 11 of Set 9 | buenos aires
# Processing Record 12 of Set 9 | lazaro cardenas
# Processing Record 13 of Set 9 | santa rosa
# Processing Record 14 of Set 9 | iquique
# Processing Record 15 of Set 9 | cayenne
# Processing Record 16 of Set 9 | enshi
# Processing Record 17 of Set 9 | tukrah
# Processing Record 18 of Set 9 | ugoofaaru
# Processing Record 19 of Set 9 | manzanillo
# Processing Record 20 of Set 9 | nakhon sawan
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 9 | saint-joseph
# Processing Record 25 of Set 9 | peshkopi
# Processing Record 26 of Set 9 | nyurba
# Processing Record 27 of Set 9 | hokitika
# Processing Record 28 of Set 9 | slave lake
# Processing Record 29 of Set 9 | djougou
# Processing Record 30 of Set 9 | kavieng
# Processing Record 31 of Set 9 | satipo
# Processing Record 32 of Set 9 | astana
# Processing Record 33 of Set 9 | san agustin
# Processing Record 34 of Set 9 | bajil
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | dehloran
# Processing Record 37 of Set 9 | iralaya
# Processing Record 38 of Set 9 | kamaishi
# Processing Record 39 of Set 9 | kysyl-syr
# Processing Record 40 of Set 9 | along
# Processing Record 41 of Set 9 | nabire
# Processing Record 42 of Set 9 | herat
# Processing Record 43 of Set 9 | rio das ostras
# Processing Record 44 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 9 | le port
# Processing Record 46 of Set 9 | dunda
# Processing Record 47 of Set 9 | manzhouli
# Processing Record 48 of Set 9 | salamanca
# Processing Record 49 of Set 9 | tuatapere
# Processing Record 50 of Set 9 | bom sucesso
# Processing Record 1 of Set 10 | danielskuil
# Processing Record 2 of Set 10 | abha
# Processing Record 3 of Set 10 | mandalgovi
# Processing Record 4 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 10 | orange
# Processing Record 6 of Set 10 | dayong
# Processing Record 7 of Set 10 | sonoita
# Processing Record 8 of Set 10 | touros
# Processing Record 9 of Set 10 | kalyan
# Processing Record 10 of Set 10 | bredy
# Processing Record 11 of Set 10 | shakhta
# Processing Record 12 of Set 10 | kutum
# Processing Record 13 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 10 | darmanesti
# Processing Record 15 of Set 10 | benjamin hill
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | buraydah
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | daru
# Processing Record 20 of Set 10 | griffith
# Processing Record 21 of Set 10 | fairbanks
# Processing Record 22 of Set 10 | baker city
# Processing Record 23 of Set 10 | hirado
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | sinnamary
# Processing Record 26 of Set 10 | nalut
# Processing Record 27 of Set 10 | mumford
# Processing Record 28 of Set 10 | malumfashi
# Processing Record 29 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 10 | novikovo
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | kyabe
# Processing Record 33 of Set 10 | grindavik
# Processing Record 34 of Set 10 | soto la marina
# Processing Record 35 of Set 10 | batticaloa
# Processing Record 36 of Set 10 | balezino
# Processing Record 37 of Set 10 | urumqi
# Processing Record 38 of Set 10 | hammerfest
# Processing Record 39 of Set 10 | spartanburg
# Processing Record 40 of Set 10 | atbasar
# Processing Record 41 of Set 10 | mamallapuram
# Processing Record 42 of Set 10 | sri aman
# Processing Record 43 of Set 10 | cartagena del chaira
# Processing Record 44 of Set 10 | catamarca
# Processing Record 45 of Set 10 | havre-saint-pierre
# Processing Record 46 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 10 | cabedelo
# Processing Record 50 of Set 10 | takapau
# Processing Record 1 of Set 11 | orlik
# Processing Record 2 of Set 11 | likasi
# Processing Record 3 of Set 11 | necochea
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | luderitz
# Processing Record 6 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 11 | mount gambier
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | deoband
# Processing Record 10 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 11 | alyangula
# Processing Record 12 of Set 11 | ayagoz
# Processing Record 13 of Set 11 | fare
# Processing Record 14 of Set 11 | carutapera
# Processing Record 15 of Set 11 | sibolga
# Processing Record 16 of Set 11 | colares
# Processing Record 17 of Set 11 | haines junction
# Processing Record 18 of Set 11 | paoua
# Processing Record 19 of Set 11 | briancon
# Processing Record 20 of Set 11 | chapais
# Processing Record 21 of Set 11 | tommot
# Processing Record 22 of Set 11 | marquette
# Processing Record 23 of Set 11 | lukovetskiy
# Processing Record 24 of Set 11 | ganzhou
# Processing Record 25 of Set 11 | labuhan
# Processing Record 26 of Set 11 | lianyuan
# Processing Record 27 of Set 11 | vao
# Processing Record 28 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 11 | nimes
# Processing Record 30 of Set 11 | zaysan
# Processing Record 31 of Set 11 | nizhnyaya omka
# Processing Record 32 of Set 11 | pemba
# Processing Record 33 of Set 11 | halifax
# Processing Record 34 of Set 11 | murray
# Processing Record 35 of Set 11 | tupik
# Processing Record 36 of Set 11 | sungaipenuh
# Processing Record 37 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | almaznyy
# Processing Record 39 of Set 11 | byron bay
# Processing Record 40 of Set 11 | san patricio
# Processing Record 41 of Set 11 | yeppoon
# Processing Record 42 of Set 11 | lima
# Processing Record 43 of Set 11 | hennenman
# Processing Record 44 of Set 11 | genhe
# Processing Record 45 of Set 11 | rognan
# Processing Record 46 of Set 11 | moron
# Processing Record 47 of Set 11 | turukhansk
# Processing Record 48 of Set 11 | ukiah
# Processing Record 49 of Set 11 | haileybury
# Processing Record 50 of Set 11 | alta floresta
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | hovd
# Processing Record 3 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 4 of Set 12 | sakakah
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | asau
# Processing Record 7 of Set 12 | hudson bay
# Processing Record 8 of Set 12 | nouadhibou
# Processing Record 9 of Set 12 | molteno
# Processing Record 10 of Set 12 | inhambane
# Processing Record 11 of Set 12 | tongchuan
# Processing Record 12 of Set 12 | gamba
# Processing Record 13 of Set 12 | ferrandina
# Processing Record 14 of Set 12 | igarka
# Processing Record 15 of Set 12 | racari
# Processing Record 16 of Set 12 | cap-aux-meules
# Processing Record 17 of Set 12 | santa clarita
# Processing Record 18 of Set 12 | goundam
# Processing Record 19 of Set 12 | palia kalan
# Processing Record 20 of Set 12 | magadan
# Processing Record 21 of Set 12 | bengkulu
# Processing Record 22 of Set 12 | waitati
# Processing Record 23 of Set 12 | mogok
# Processing Record 24 of Set 12 | evensk
# Processing Record 25 of Set 12 | kedrovyy
# Processing Record 26 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 12 | port hardy
# Processing Record 28 of Set 12 | onega
# Processing Record 29 of Set 12 | conde
# Processing Record 30 of Set 12 | diffa
# Processing Record 31 of Set 12 | lasa
# Processing Record 32 of Set 12 | grand gaube
# Processing Record 33 of Set 12 | la ronge
# Processing Record 34 of Set 12 | mogadishu
# Processing Record 35 of Set 12 | baruun-urt
# Processing Record 36 of Set 12 | penzance
# Processing Record 37 of Set 12 | spassk-ryazanskiy
# Processing Record 38 of Set 12 | vostok
# Processing Record 39 of Set 12 | kumsi
# Processing Record 40 of Set 12 | togur
# Processing Record 41 of Set 12 | nemuro
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 12 | skegness
# Processing Record 44 of Set 12 | oktyabrskoye
# Processing Record 45 of Set 12 | wuwei
# Processing Record 46 of Set 12 | acapulco
# Processing Record 47 of Set 12 | severo-kurilsk
# Processing Record 48 of Set 12 | george town
# Processing Record 49 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 50 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 13 | diapaga
# Processing Record 2 of Set 13 | palmer
# Processing Record 3 of Set 13 | emden
# Processing Record 4 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 5 of Set 13 | jhargram
# Processing Record 6 of Set 13 | vorobyevka
# Processing Record 7 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 13 | peniche
# Processing Record 9 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 10 of Set 13 | yhu
# Processing Record 11 of Set 13 | visnes
# Processing Record 12 of Set 13 | llanes
# Processing Record 13 of Set 13 | teguldet
# Processing Record 14 of Set 13 | rio gallegos
# Processing Record 15 of Set 13 | camana
# Processing Record 16 of Set 13 | asyut
# Processing Record 17 of Set 13 | helmsdale
# Processing Record 18 of Set 13 | kargasok
# Processing Record 19 of Set 13 | billings
# Processing Record 20 of Set 13 | wanlaweyn
# Processing Record 21 of Set 13 | lexington
# Processing Record 22 of Set 13 | yukamenskoye
# Processing Record 23 of Set 13 | xai-xai
# Processing Record 24 of Set 13 | batemans bay
# Processing Record 25 of Set 13 | sydney
# Processing Record 26 of Set 13 | padang
# Processing Record 27 of Set 13 | lapeer
# Processing Record 28 of Set 13 | solnechnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 571

# %%
city_data
# Out:
# [{'City': 'Keetmanshoop',
#   'Lat': -26.5833,
#   'Lng': 18.1333,
#   'Max Temp': 66.2,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'NA',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 64,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 91.4,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'MY',
#   'Date': '2021-03-15 08:06:49'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:07:35'},
#  {'City': 'Ust-Maya',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': 15.87,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.35,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 12.74,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 4.09,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 19.99,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 10.67,
#   'Country': 'US',
#   'Date': '2021-03-15 08:07:02'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 82,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:07'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TO',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 80.31,
#   'Humidity': 76,
#   'Cloudiness': 47,
#   'Wind Speed': 6.67,
#   'Country': 'PF',
#   'Date': '2021-03-15 08:11:26'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -17.97,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 6.24,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:27'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 72.73,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 16.87,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:11:27'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 57,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:07:01'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 32,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:27'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 55,
#   'Humidity': 72,
#   'Cloudiness': 5,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:28'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 54.5,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 13.76,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:11:28'},
#  {'City': 'Pozo Colorado',
#   'Lat': -23.4923,
#   'Lng': -58.7972,
#   'Max Temp': 73.62,
#   'Humidity': 73,
#   'Cloudiness': 98,
#   'Wind Speed': 2.91,
#   'Country': 'PY',
#   'Date': '2021-03-15 08:11:28'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 77,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:09:55'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 32,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:28'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 73,
#   'Humidity': 97,
#   'Cloudiness': 27,
#   'Wind Speed': 5.91,
#   'Country': 'EC',
#   'Date': '2021-03-15 08:11:28'},
#  {'City': 'Victor Harbor',
#   'Lat': -35.5667,
#   'Lng': 138.6167,
#   'Max Temp': 66.99,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:55'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 66,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:31'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.54,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 9.24,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:06:54'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 70,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:11:29'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 83.17,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 7.63,
#   'Country': 'OM',
#   'Date': '2021-03-15 08:11:29'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55,
#   'Humidity': 72,
#   'Cloudiness': 64,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:29'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 39.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:30'},
#  {'City': 'Alamos',
#   'Lat': 27.0167,
#   'Lng': -108.9333,
#   'Max Temp': 55.99,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:11:30'},
#  {'City': 'Galesburg',
#   'Lat': 40.9478,
#   'Lng': -90.3712,
#   'Max Temp': 41,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:30'},
#  {'City': 'Japura',
#   'Lat': -0.3167,
#   'Lng': 102.35,
#   'Max Temp': 87.6,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4.03,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:11:30'},
#  {'City': 'Kathmandu',
#   'Lat': 27.7167,
#   'Lng': 85.3167,
#   'Max Temp': 73.4,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'NP',
#   'Date': '2021-03-15 08:11:12'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 46,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:31'},
#  {'City': 'Noyabrsk',
#   'Lat': 63.1994,
#   'Lng': 75.4507,
#   'Max Temp': 20.75,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 16.73,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:31'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 73.4,
#   'Humidity': 28,
#   'Cloudiness': 22,
#   'Wind Speed': 4.61,
#   'Country': 'SA',
#   'Date': '2021-03-15 08:07:51'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 57,
#   'Humidity': 47,
#   'Cloudiness': 17,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:31'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:07:31'},
#  {'City': 'Bongor',
#   'Lat': 10.2806,
#   'Lng': 15.3722,
#   'Max Temp': 93.94,
#   'Humidity': 24,
#   'Cloudiness': 92,
#   'Wind Speed': 12.17,
#   'Country': 'TD',
#   'Date': '2021-03-15 08:11:32'},
#  {'City': 'Hlotse',
#   'Lat': -28.8718,
#   'Lng': 28.045,
#   'Max Temp': 71.28,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Country': 'LS',
#   'Date': '2021-03-15 08:07:30'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 72.12,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:07:44'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -17.3,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 6.67,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 84.45,
#   'Humidity': 54,
#   'Cloudiness': 39,
#   'Wind Speed': 12.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 34,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 66.43,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 14.09,
#   'Country': 'LY',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 3.18,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.28,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:33'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 21.2,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -13,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 37.4,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 13.42,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Esquias',
#   'Lat': 14.7333,
#   'Lng': -87.3667,
#   'Max Temp': 63.7,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 3.69,
#   'Country': 'HN',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 35.01,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 64.99,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Birjand',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 60.8,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'IR',
#   'Date': '2021-03-15 08:11:34'},
#  {'City': 'Phichit',
#   'Lat': 16.25,
#   'Lng': 100.4167,
#   'Max Temp': 100,
#   'Humidity': 39,
#   'Cloudiness': 80,
#   'Wind Speed': 5.68,
#   'Country': 'TH',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:10:44'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 75.2,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Luba',
#   'Lat': 3.4568,
#   'Lng': 8.5547,
#   'Max Temp': 81.41,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'GQ',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -9.15,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 7.63,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 35.6,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:35'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 25.32,
#   'Country': 'RE',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 71.64,
#   'Humidity': 86,
#   'Cloudiness': 19,
#   'Wind Speed': 4.72,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 57.99,
#   'Humidity': 50,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:07:14'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 23.2,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 20.27,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:06:59'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4.52,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -4,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 66.2,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'JP',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Ulagan',
#   'Lat': 50.6321,
#   'Lng': 87.9563,
#   'Max Temp': 29.77,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.21,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:36'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 69.46,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Country': 'CV',
#   'Date': '2021-03-15 08:07:53'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 65.34,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.11,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 43,
#   'Humidity': 91,
#   'Cloudiness': 22,
#   'Wind Speed': 3.51,
#   'Country': 'PT',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.15,
#   'Humidity': 71,
#   'Cloudiness': 3,
#   'Wind Speed': 10.09,
#   'Country': 'PF',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 77.49,
#   'Humidity': 74,
#   'Cloudiness': 62,
#   'Wind Speed': 7.9,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 3,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:07:52'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 15.03,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:37'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -4.58,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:38'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 61.5,
#   'Humidity': 92,
#   'Cloudiness': 1,
#   'Wind Speed': 2.42,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:18'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 26.6,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:38'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75.99,
#   'Humidity': 68,
#   'Cloudiness': 10,
#   'Wind Speed': 1.99,
#   'Country': 'HK',
#   'Date': '2021-03-15 08:10:31'},
#  {'City': 'Kumylzhenskaya',
#   'Lat': 49.8809,
#   'Lng': 42.5898,
#   'Max Temp': 34,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:38'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:38'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 29.19,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 17.25,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 10.4,
#   'Humidity': 61,
#   'Cloudiness': 56,
#   'Wind Speed': 9.22,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 79.47,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 14.58,
#   'Country': 'KI',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.67,
#   'Humidity': 94,
#   'Cloudiness': 23,
#   'Wind Speed': 3.13,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Perelyub',
#   'Lat': 51.8667,
#   'Lng': 50.3667,
#   'Max Temp': 14.2,
#   'Humidity': 83,
#   'Cloudiness': 17,
#   'Wind Speed': 12.26,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 18,
#   'Humidity': 35,
#   'Cloudiness': 33,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:39'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 53.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:07:19'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Lat': -0.1303,
#   'Lng': -67.0892,
#   'Max Temp': 72.73,
#   'Humidity': 92,
#   'Cloudiness': 92,
#   'Wind Speed': 1.63,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:18'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'FO',
#   'Date': '2021-03-15 08:11:40'},
#  {'City': 'Miranda',
#   'Lat': 3.2499,
#   'Lng': -76.2281,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CO',
#   'Date': '2021-03-15 08:07:54'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 66.2,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'CV',
#   'Date': '2021-03-15 08:11:41'},
#  {'City': 'Lodja',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 77.7,
#   'Humidity': 90,
#   'Cloudiness': 89,
#   'Wind Speed': 3.09,
#   'Country': 'CD',
#   'Date': '2021-03-15 08:11:41'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -8.27,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 15.21,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:41'},
#  {'City': 'Chengde',
#   'Lat': 40.9725,
#   'Lng': 117.9361,
#   'Max Temp': 47.34,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 20.83,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:07:15'},
#  {'City': 'Lao Cai',
#   'Lat': 22.4833,
#   'Lng': 103.95,
#   'Max Temp': 86.81,
#   'Humidity': 55,
#   'Cloudiness': 22,
#   'Wind Speed': 4.92,
#   'Country': 'VN',
#   'Date': '2021-03-15 08:11:12'},
#  {'City': 'Ladario',
#   'Lat': -19.0047,
#   'Lng': -57.6017,
#   'Max Temp': 72.81,
#   'Humidity': 93,
#   'Cloudiness': 92,
#   'Wind Speed': 0.43,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:30'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 81.48,
#   'Humidity': 72,
#   'Cloudiness': 28,
#   'Wind Speed': 6.64,
#   'Country': 'PG',
#   'Date': '2021-03-15 08:11:42'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 75,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:11:42'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 21,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 15.28,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:42'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 0.28,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.35,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 75.15,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 12.46,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Buchanan',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.93,
#   'Country': 'LR',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -1.5,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Tooele',
#   'Lat': 40.5308,
#   'Lng': -112.2983,
#   'Max Temp': 43,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Falun',
#   'Lat': 60.6036,
#   'Lng': 15.626,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'SE',
#   'Date': '2021-03-15 08:06:59'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 37,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -8.82,
#   'Humidity': 64,
#   'Cloudiness': 47,
#   'Wind Speed': 6.06,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 71.91,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:43'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 35.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:07:27'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3.78,
#   'Country': 'AO',
#   'Date': '2021-03-15 08:07:01'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 19.57,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:44'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Date': '2021-03-15 08:11:44'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 55,
#   'Humidity': 69,
#   'Cloudiness': 21,
#   'Wind Speed': 1.99,
#   'Country': 'PT',
#   'Date': '2021-03-15 08:11:44'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:01'},
#  {'City': 'Rosetown',
#   'Lat': 51.5501,
#   'Lng': -108.0014,
#   'Max Temp': 36,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:44'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 83.39,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:07:56'},
#  {'City': 'Corum',
#   'Lat': 40.5,
#   'Lng': 34.75,
#   'Max Temp': 50.2,
#   'Humidity': 60,
#   'Cloudiness': 81,
#   'Wind Speed': 7.63,
#   'Country': 'TR',
#   'Date': '2021-03-15 08:07:54'},
#  {'City': 'Ahuimanu',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:45'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -7.2,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:45'},
#  {'City': 'Rabo De Peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'PT',
#   'Date': '2021-03-15 08:11:45'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -5.82,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:45'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 49.28,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:07:14'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 84.79,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 8.9,
#   'Country': 'PH',
#   'Date': '2021-03-15 08:11:45'},
#  {'City': 'Johnstown',
#   'Lat': 40.3267,
#   'Lng': -78.922,
#   'Max Temp': 21,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Porto Torres',
#   'Lat': 40.835,
#   'Lng': 8.3972,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'IT',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 78.46,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 2.39,
#   'Country': 'GH',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 69.66,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.13,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:47'},
#  {'City': 'Labuan',
#   'Lat': 5.2767,
#   'Lng': 115.2417,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MY',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Puerto Asis',
#   'Lat': 0.5133,
#   'Lng': -76.5007,
#   'Max Temp': 69.82,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'CO',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Cloudiness': 70,
#   'Wind Speed': 10,
#   'Country': 'GB',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Beira',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'MZ',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Nenjiang',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': 35.62,
#   'Humidity': 43,
#   'Cloudiness': 56,
#   'Wind Speed': 10.83,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:11:46'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 21.2,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:47'},
#  {'City': 'Olonets',
#   'Lat': 60.9847,
#   'Lng': 32.9698,
#   'Max Temp': 33.58,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:47'},
#  {'City': 'Puerto Madero',
#   'Lat': 14.7208,
#   'Lng': -92.4215,
#   'Max Temp': 79.25,
#   'Humidity': 71,
#   'Cloudiness': 88,
#   'Wind Speed': 5.79,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:11:47'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 66.87,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.43,
#   'Country': 'TL',
#   'Date': '2021-03-15 08:11:47'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:11:47'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 67.46,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 15.52,
#   'Country': 'NA',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Korgen',
#   'Lat': 66.0771,
#   'Lng': 13.8153,
#   'Max Temp': 36,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 17.78,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 84.67,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 6.44,
#   'Country': 'MV',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -13,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.53,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 64.35,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 20.56,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:07:44'},
#  {'City': 'Takab',
#   'Lat': 36.4009,
#   'Lng': 47.1133,
#   'Max Temp': 45.97,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Country': 'IR',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp': 35.55,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.37,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 82.53,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 0.07,
#   'Country': 'PG',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:48'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 62.2,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Haimen',
#   'Lat': 23.1935,
#   'Lng': 116.6142,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 6.71,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 83.34,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 0.94,
#   'Country': 'MV',
#   'Date': '2021-03-15 08:07:54'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'BB',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Susaki',
#   'Lat': 33.3667,
#   'Lng': 133.2833,
#   'Max Temp': 62.6,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2021-03-15 08:07:14'},
#  {'City': 'Warrnambool',
#   'Lat': -38.3833,
#   'Lng': 142.4833,
#   'Max Temp': 62.01,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind Speed': 9.44,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:28'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 80.26,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 3.6,
#   'Country': 'GH',
#   'Date': '2021-03-15 08:06:51'},
#  {'City': 'Marienburg',
#   'Lat': 54.0359,
#   'Lng': 19.0266,
#   'Max Temp': 39.99,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 9.37,
#   'Country': 'PL',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 61.36,
#   'Humidity': 87,
#   'Cloudiness': 10,
#   'Wind Speed': 1.74,
#   'Country': 'UY',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 79.79,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 3.83,
#   'Country': 'GA',
#   'Date': '2021-03-15 08:07:57'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 26.6,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 46.04,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:49'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 82,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 66,
#   'Humidity': 52,
#   'Cloudiness': 11,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Lynchburg',
#   'Lat': 37.4138,
#   'Lng': -79.1423,
#   'Max Temp': 44.6,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': 37.76,
#   'Humidity': 78,
#   'Cloudiness': 92,
#   'Wind Speed': 13.31,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 64,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'NA',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -11.69,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 3.67,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:07:06'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 15.8,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IS',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 27,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -17.9,
#   'Humidity': 97,
#   'Cloudiness': 8,
#   'Wind Speed': 5.19,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:50'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 17.47,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 5.28,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 80.6,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 79.07,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 2.86,
#   'Country': 'SB',
#   'Date': '2021-03-15 08:07:23'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.42,
#   'Humidity': 78,
#   'Cloudiness': 48,
#   'Wind Speed': 13.78,
#   'Country': 'PF',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Seminole',
#   'Lat': 28.7086,
#   'Lng': -81.2081,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 70.77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Country': 'BS',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Flic En Flac',
#   'Lat': -20.2742,
#   'Lng': 57.3631,
#   'Max Temp': 82,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'Jiangyou',
#   'Lat': 31.7667,
#   'Lng': 104.7167,
#   'Max Temp': 77.58,
#   'Humidity': 44,
#   'Cloudiness': 11,
#   'Wind Speed': 3.74,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:07:45'},
#  {'City': 'Gazojak',
#   'Lat': 41.1875,
#   'Lng': 61.4036,
#   'Max Temp': 30.24,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.66,
#   'Country': 'TM',
#   'Date': '2021-03-15 08:07:41'},
#  {'City': 'Luza',
#   'Lat': 60.6308,
#   'Lng': 47.2512,
#   'Max Temp': 30.83,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:51'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -7.01,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 0.94,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 74.93,
#   'Humidity': 89,
#   'Cloudiness': 68,
#   'Wind Speed': 7.31,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 51.58,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 7.36,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 86.38,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 11.36,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Panama City',
#   'Lat': 8.9936,
#   'Lng': -79.5197,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'PA',
#   'Date': '2021-03-15 08:07:43'},
#  {'City': 'Rudbar',
#   'Lat': 30.15,
#   'Lng': 62.6,
#   'Max Temp': 70.99,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Country': 'AF',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Calbuco',
#   'Lat': -41.768,
#   'Lng': -73.1273,
#   'Max Temp': 51.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Jertih',
#   'Lat': 5.7336,
#   'Lng': 102.4897,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'MY',
#   'Date': '2021-03-15 08:10:51'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 84.74,
#   'Humidity': 68,
#   'Cloudiness': 18,
#   'Wind Speed': 9.64,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:11:52'},
#  {'City': 'Atasu',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 8.55,
#   'Humidity': 77,
#   'Cloudiness': 14,
#   'Wind Speed': 4,
#   'Country': 'KZ',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Pokaran',
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp': 94.93,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'PH',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Yichang',
#   'Lat': 30.7144,
#   'Lng': 111.2847,
#   'Max Temp': 75.99,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:07:31'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 55.36,
#   'Humidity': 88,
#   'Cloudiness': 91,
#   'Wind Speed': 2.42,
#   'Country': 'CL',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 91.4,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'LK',
#   'Date': '2021-03-15 08:07:55'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 25.32,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 71.11,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 5.28,
#   'Country': 'GM',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 85.77,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 15.7,
#   'Country': 'MM',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 37.99,
#   'Humidity': 91,
#   'Cloudiness': 7,
#   'Wind Speed': 3.38,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:53'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 39.2,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 37.98,
#   'Country': 'GL',
#   'Date': '2021-03-15 08:11:54'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'PW',
#   'Date': '2021-03-15 08:11:54'},
#  {'City': 'Magnor',
#   'Lat': 59.9511,
#   'Lng': 12.1996,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'SE',
#   'Date': '2021-03-15 08:11:55'},
#  {'City': 'Petrolina',
#   'Lat': -9.3986,
#   'Lng': -40.5008,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:14'},
#  {'City': 'Karasjok',
#   'Lat': 69.4719,
#   'Lng': 25.5112,
#   'Max Temp': 26.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:55'},
#  {'City': 'Dinhata',
#   'Lat': 26.1333,
#   'Lng': 89.4667,
#   'Max Temp': 95.11,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 11.39,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:11:56'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 69.01,
#   'Humidity': 35,
#   'Cloudiness': 24,
#   'Wind Speed': 1.99,
#   'Country': 'IL',
#   'Date': '2021-03-15 08:11:56'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:07:00'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 82,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'PF',
#   'Date': '2021-03-15 08:11:56'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 66,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:07:53'},
#  {'City': 'Istmina',
#   'Lat': 5.1605,
#   'Lng': -76.684,
#   'Max Temp': 73.06,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.27,
#   'Country': 'CO',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 69.03,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Country': 'MR',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Farim',
#   'Lat': 12.4839,
#   'Lng': -15.2217,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.89,
#   'Country': 'GW',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Boende',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 82.26,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'CD',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Amapa',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 69.3,
#   'Humidity': 99,
#   'Cloudiness': 45,
#   'Wind Speed': 1.36,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:55'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 64.4,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:07:36'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 3.18,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Sarahan',
#   'Lat': 31.5167,
#   'Lng': 77.8,
#   'Max Temp': 62.01,
#   'Humidity': 25,
#   'Cloudiness': 45,
#   'Wind Speed': 5.41,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 30.69,
#   'Humidity': 76,
#   'Cloudiness': 44,
#   'Wind Speed': 12.01,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 64.74,
#   'Humidity': 95,
#   'Cloudiness': 56,
#   'Wind Speed': 2.53,
#   'Country': 'VE',
#   'Date': '2021-03-15 08:07:51'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 71.71,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:07:34'},
#  {'City': 'Silva Jardim',
#   'Lat': -22.6508,
#   'Lng': -42.3917,
#   'Max Temp': 71.31,
#   'Humidity': 94,
#   'Cloudiness': 88,
#   'Wind Speed': 1.74,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:57'},
#  {'City': 'Mansa',
#   'Lat': 29.9833,
#   'Lng': 75.3833,
#   'Max Temp': 93.92,
#   'Humidity': 10,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Lumbog',
#   'Lat': 7.5581,
#   'Lng': 123.2014,
#   'Max Temp': 82.4,
#   'Humidity': 71,
#   'Cloudiness': 9,
#   'Wind Speed': 5.79,
#   'Country': 'PH',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 48.99,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 1.59,
#   'Country': 'US',
#   'Date': '2021-03-15 08:07:32'},
#  {'City': 'Kilemary',
#   'Lat': 56.7783,
#   'Lng': 46.8659,
#   'Max Temp': 33.19,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 12.95,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Mapiri',
#   'Lat': -15.25,
#   'Lng': -68.1667,
#   'Max Temp': 64.76,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Country': 'BO',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Chegdomyn',
#   'Lat': 51.1167,
#   'Lng': 133.0167,
#   'Max Temp': 41.2,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 9.89,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'BJ',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Wasilla',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': 19.99,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 1.95,
#   'Country': 'US',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': -1.14,
#   'Humidity': 74,
#   'Cloudiness': 85,
#   'Wind Speed': 7.99,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Basqal',
#   'Lat': 40.7552,
#   'Lng': 48.391,
#   'Max Temp': 42.8,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'AZ',
#   'Date': '2021-03-15 08:11:58'},
#  {'City': 'Notse',
#   'Lat': 6.95,
#   'Lng': 1.1667,
#   'Max Temp': 81.91,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04,
#   'Country': 'TG',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'JP',
#   'Date': '2021-03-15 08:11:00'},
#  {'City': 'Sena Madureira',
#   'Lat': -9.0656,
#   'Lng': -68.6569,
#   'Max Temp': 71.65,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Takaka',
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp': 66.99,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Montepulciano',
#   'Lat': 43.1017,
#   'Lng': 11.7868,
#   'Max Temp': 46.99,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 0.43,
#   'Country': 'IT',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 85.51,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Mineros',
#   'Lat': -17.1167,
#   'Lng': -63.2333,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'BO',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Alta',
#   'Lat': 69.9689,
#   'Lng': 23.2717,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 3.87,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'PT',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -13,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 26.46,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Raga',
#   'Lat': 8.4596,
#   'Lng': 25.678,
#   'Max Temp': 94.15,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'SS',
#   'Date': '2021-03-15 08:11:59'},
#  {'City': 'Barhiya',
#   'Lat': 25.2833,
#   'Lng': 86.0333,
#   'Max Temp': 98.38,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 11.79,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:12:00'},
#  {'City': 'Wolgast',
#   'Lat': 54.05,
#   'Lng': 13.7667,
#   'Max Temp': 41,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'DE',
#   'Date': '2021-03-15 08:12:00'},
#  {'City': 'Mkushi',
#   'Lat': -13.6202,
#   'Lng': 29.3939,
#   'Max Temp': 69.91,
#   'Humidity': 84,
#   'Cloudiness': 80,
#   'Wind Speed': 7.81,
#   'Country': 'ZM',
#   'Date': '2021-03-15 08:12:00'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -13.04,
#   'Humidity': 99,
# ...
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 1.88,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:12:31'},
#  {'City': 'Almaznyy',
#   'Lat': 48.0448,
#   'Lng': 40.045,
#   'Max Temp': 41,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:33'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:12:33'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 60.01,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Lima',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'PE',
#   'Date': '2021-03-15 08:10:59'},
#  {'City': 'Hennenman',
#   'Lat': -27.9765,
#   'Lng': 27.0242,
#   'Max Temp': 78.01,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:07:50'},
#  {'City': 'Genhe',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': 14.07,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 15.7,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Rognan',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 34,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 3.56,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 73,
#   'Humidity': 69,
#   'Cloudiness': 57,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 13.82,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Ukiah',
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Haileybury',
#   'Lat': 47.449,
#   'Lng': -79.6373,
#   'Max Temp': 3.2,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:12:34'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 69.08,
#   'Humidity': 98,
#   'Cloudiness': 46,
#   'Wind Speed': 2.01,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 62.24,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 22.57,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 26.47,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Country': 'MN',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 68,
#   'Humidity': 22,
#   'Cloudiness': 8,
#   'Wind Speed': 3.44,
#   'Country': 'SA',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 45,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'RO',
#   'Date': '2021-03-15 08:12:35'},
#  {'City': 'Hudson Bay',
#   'Lat': 52.85,
#   'Lng': -102.3842,
#   'Max Temp': 33.71,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 10.98,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'MR',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Molteno',
#   'Lat': -31.3968,
#   'Lng': 26.3625,
#   'Max Temp': 72.77,
#   'Humidity': 40,
#   'Cloudiness': 90,
#   'Wind Speed': 18.88,
#   'Country': 'ZA',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'MZ',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Tongchuan',
#   'Lat': 35.0806,
#   'Lng': 109.0897,
#   'Max Temp': 70.5,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 8.14,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 75.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Country': 'GA',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Ferrandina',
#   'Lat': 40.5012,
#   'Lng': 16.4547,
#   'Max Temp': 48.99,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Country': 'IT',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': -5.96,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 2.95,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Racari',
#   'Lat': 44.6333,
#   'Lng': 25.7333,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'RO',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Cap-Aux-Meules',
#   'Lat': 47.3821,
#   'Lng': -61.8597,
#   'Max Temp': 15.8,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 25.32,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:12:36'},
#  {'City': 'Santa Clarita',
#   'Lat': 34.3917,
#   'Lng': -118.5426,
#   'Max Temp': 48.99,
#   'Humidity': 84,
#   'Cloudiness': 74,
#   'Wind Speed': 2.86,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Goundam',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 76.8,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 10.38,
#   'Country': 'ML',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Palia Kalan',
#   'Lat': 28.45,
#   'Lng': 80.5833,
#   'Max Temp': 97.25,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 12.41,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 11.14,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 4.81,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 85.06,
#   'Humidity': 65,
#   'Cloudiness': 49,
#   'Wind Speed': 6.11,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Waitati',
#   'Lat': -45.75,
#   'Lng': 170.5667,
#   'Max Temp': 57,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 8.99,
#   'Country': 'NZ',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Mogok',
#   'Lat': 22.9167,
#   'Lng': 96.5,
#   'Max Temp': 87.26,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Country': 'MM',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': -6.61,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Kedrovyy',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp': 21.2,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:37'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Onega',
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp': 30.04,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.14,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Diffa',
#   'Lat': 13.3154,
#   'Lng': 12.6113,
#   'Max Temp': 90.81,
#   'Humidity': 9,
#   'Cloudiness': 32,
#   'Wind Speed': 7.87,
#   'Country': 'NE',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 42.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'IT',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 82,
#   'Humidity': 83,
#   'Cloudiness': 71,
#   'Wind Speed': 8.99,
#   'Country': 'MU',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 41,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'SO',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 29.52,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 18.59,
#   'Country': 'MN',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Penzance',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 48.99,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'GB',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Spassk-Ryazanskiy',
#   'Lat': 54.4072,
#   'Lng': 40.3806,
#   'Max Temp': 32.63,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 17.31,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:39'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 41.23,
#   'Humidity': 81,
#   'Cloudiness': 15,
#   'Wind Speed': 3.15,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:40'},
#  {'City': 'Kumsi',
#   'Lat': 14.0667,
#   'Lng': 75.4,
#   'Max Temp': 95.34,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 9.24,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:12:08'},
#  {'City': 'Togur',
#   'Lat': 58.3631,
#   'Lng': 82.8265,
#   'Max Temp': 18.39,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:40'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 42.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Date': '2021-03-15 08:12:40'},
#  {'City': 'Skegness',
#   'Lat': 53.1436,
#   'Lng': 0.3363,
#   'Max Temp': 44.01,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'GB',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'Oktyabrskoye',
#   'Lat': 43.0645,
#   'Lng': 44.7417,
#   'Max Temp': 28.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'Wuwei',
#   'Lat': 37.9281,
#   'Lng': 102.6414,
#   'Max Temp': 55.76,
#   'Humidity': 20,
#   'Cloudiness': 97,
#   'Wind Speed': 8.57,
#   'Country': 'CN',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 72.16,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.5,
#   'Country': 'MX',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 36.1,
#   'Humidity': 93,
#   'Cloudiness': 70,
#   'Wind Speed': 11.01,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'George Town',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 91.4,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'MY',
#   'Date': '2021-03-15 08:12:41'},
#  {'City': 'Diapaga',
#   'Lat': 12.0708,
#   'Lng': 1.7889,
#   'Max Temp': 86.25,
#   'Humidity': 22,
#   'Cloudiness': 53,
#   'Wind Speed': 5.03,
#   'Country': 'BF',
#   'Date': '2021-03-15 08:12:42'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 19.4,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 21.85,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:42'},
#  {'City': 'Emden',
#   'Lat': 53.3667,
#   'Lng': 7.2167,
#   'Max Temp': 43,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'DE',
#   'Date': '2021-03-15 08:12:42'},
#  {'City': 'Jhargram',
#   'Lat': 22.45,
#   'Lng': 86.9833,
#   'Max Temp': 99.81,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 1.92,
#   'Country': 'IN',
#   'Date': '2021-03-15 08:12:43'},
#  {'City': 'Vorobyevka',
#   'Lat': 50.6451,
#   'Lng': 40.9245,
#   'Max Temp': 30.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 18.05,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:43'},
#  {'City': 'Peniche',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 53.01,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'PT',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Yhu',
#   'Lat': -25.05,
#   'Lng': -55.9167,
#   'Max Temp': 68.32,
#   'Humidity': 64,
#   'Cloudiness': 19,
#   'Wind Speed': 2.77,
#   'Country': 'PY',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Visnes',
#   'Lat': 59.3556,
#   'Lng': 5.2242,
#   'Max Temp': 39.2,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'NO',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Llanes',
#   'Lat': 43.4198,
#   'Lng': -4.7549,
#   'Max Temp': 48,
#   'Humidity': 98,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'ES',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 16.45,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AR',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Camana',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 70.74,
#   'Humidity': 87,
#   'Cloudiness': 88,
#   'Wind Speed': 7.31,
#   'Country': 'PE',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'EG',
#   'Date': '2021-03-15 08:12:44'},
#  {'City': 'Helmsdale',
#   'Lat': 58.1168,
#   'Lng': -3.6517,
#   'Max Temp': 42.8,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'GB',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Kargasok',
#   'Lat': 59.0556,
#   'Lng': 80.8572,
#   'Max Temp': 19.65,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.93,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Billings',
#   'Lat': 45.7833,
#   'Lng': -108.5007,
#   'Max Temp': 35.01,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Wanlaweyn',
#   'Lat': 2.6185,
#   'Lng': 44.8938,
#   'Max Temp': 90.75,
#   'Humidity': 43,
#   'Cloudiness': 80,
#   'Wind Speed': 12.35,
#   'Country': 'SO',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Lexington',
#   'Lat': 37.9887,
#   'Lng': -84.4777,
#   'Max Temp': 46,
#   'Humidity': 42,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Yukamenskoye',
#   'Lat': 57.8865,
#   'Lng': 52.2416,
#   'Max Temp': 26.53,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 13.62,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 80.11,
#   'Humidity': 65,
#   'Cloudiness': 79,
#   'Wind Speed': 9.31,
#   'Country': 'MZ',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 64.99,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Sydney',
#   'Lat': -33.8679,
#   'Lng': 151.2073,
#   'Max Temp': 69.01,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-03-15 08:09:13'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'ID',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Lapeer',
#   'Lat': 43.0514,
#   'Lng': -83.3188,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 5.3,
#   'Country': 'US',
#   'Date': '2021-03-15 08:12:45'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 36.12,
#   'Humidity': 68,
#   'Cloudiness': 36,
#   'Wind Speed': 8.23,
#   'Country': 'RU',
#   'Date': '2021-03-15 08:12:46'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Keetmanshoop -26.5833   18.1333     66.20        48           0
# 1      Flinders -34.5833  150.8552     64.00        64           0
# 2    Georgetown   5.4112  100.3354     91.40        58          20
# 3      Hermanus -34.4187   19.2345     64.00        95         100
# 4      Ust-Maya  60.4167  134.5333     15.87        86         100
# 5         Arman  59.7000  150.1667     12.74        88          99
# 6     Jamestown  42.0970  -79.2353     19.99        57           1
# 7     Busselton -33.6500  115.3333     82.00        31         100
# 8         Vaini -21.2000 -175.2000     75.20        94          75
# 9       Rikitea -23.1203 -134.9692     80.31        76          47
#
#    Wind Speed Country                 Date
# 0        2.30      NA  2021-03-15 08:11:26
# 1        6.08      AU  2021-03-15 08:11:26
# 2        9.22      MY  2021-03-15 08:06:49
# 3        1.99      ZA  2021-03-15 08:07:35
# 4       13.35      RU  2021-03-15 08:11:26
# 5        4.09      RU  2021-03-15 08:11:26
# 6       10.67      US  2021-03-15 08:07:02
# 7        4.00      AU  2021-03-15 08:07:07
# 8        2.30      TO  2021-03-15 08:11:26
# 9        6.67      PF  2021-03-15 08:11:26

# %%
new_column_order = ["City", "Country", "Date", "Date","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#            City Country                 Date                 Date      Lat  \
# 0  Keetmanshoop      NA  2021-03-15 08:11:26  2021-03-15 08:11:26 -26.5833
# 1      Flinders      AU  2021-03-15 08:11:26  2021-03-15 08:11:26 -34.5833
# 2    Georgetown      MY  2021-03-15 08:06:49  2021-03-15 08:06:49   5.4112
# 3      Hermanus      ZA  2021-03-15 08:07:35  2021-03-15 08:07:35 -34.4187
# 4      Ust-Maya      RU  2021-03-15 08:11:26  2021-03-15 08:11:26  60.4167
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   18.1333     66.20        48           0        2.30
# 1  150.8552     64.00        64           0        6.08
# 2  100.3354     91.40        58          20        9.22
# 3   19.2345     64.00        95         100        1.99
# 4  134.5333     15.87        86         100       13.35

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
