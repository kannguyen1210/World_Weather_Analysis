# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 578

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b1ab184ad140f6ea09fdcdcb4babf041

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sokoto
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | wajir
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | menongue
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | kununurra
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | los llanos de aridane
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | pinega
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | oda
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | moranbah
# Processing Record 33 of Set 1 | merauke
# Processing Record 34 of Set 1 | atar
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | kavaratti
# Processing Record 39 of Set 1 | tsaratanana
# Processing Record 40 of Set 1 | quesnel
# Processing Record 41 of Set 1 | dunedin
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | neropolis
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | samarai
# Processing Record 49 of Set 1 | biak
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | tautira
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | avera
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | kigorobya
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | buraydah
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | guerrero negro
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 2 | ibotirama
# Processing Record 15 of Set 2 | terney
# Processing Record 16 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | acapulco
# Processing Record 20 of Set 2 | zemio
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | shkotovo-22
# City not found. Skipping...
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | sivaki
# Processing Record 27 of Set 2 | ternate
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | powell river
# Processing Record 30 of Set 2 | xichang
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | adeje
# Processing Record 33 of Set 2 | banda aceh
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | kieta
# Processing Record 36 of Set 2 | magdagachi
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | matara
# Processing Record 42 of Set 2 | hovd
# Processing Record 43 of Set 2 | marathon
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | vanavara
# Processing Record 46 of Set 2 | marzuq
# Processing Record 47 of Set 2 | namatanai
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | buala
# Processing Record 1 of Set 3 | tahe
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | mircea voda
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | san joaquin
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | margate
# Processing Record 12 of Set 3 | agadez
# Processing Record 13 of Set 3 | shubarkuduk
# Processing Record 14 of Set 3 | bay roberts
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | alta floresta
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | at-bashi
# Processing Record 21 of Set 3 | foster
# Processing Record 22 of Set 3 | gizo
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | bima
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | grindavik
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | hobyo
# Processing Record 30 of Set 3 | santa vitoria do palmar
# Processing Record 31 of Set 3 | taseyevo
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | trincomalee
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | juruti
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | brae
# Processing Record 40 of Set 3 | jinhua
# Processing Record 41 of Set 3 | vychegodskiy
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | anadyr
# Processing Record 44 of Set 3 | tilichiki
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | sur
# Processing Record 48 of Set 3 | salta
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | ust-maya
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | sorland
# Processing Record 3 of Set 4 | ola
# Processing Record 4 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 5 of Set 4 | sinnamary
# Processing Record 6 of Set 4 | tura
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 4 | flinders
# Processing Record 10 of Set 4 | wattegama
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | vilcun
# Processing Record 13 of Set 4 | teguise
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | praya
# Processing Record 16 of Set 4 | pemangkat
# Processing Record 17 of Set 4 | kahului
# Processing Record 18 of Set 4 | dreznica
# Processing Record 19 of Set 4 | oxford
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | zeya
# Processing Record 22 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 23 of Set 4 | flin flon
# Processing Record 24 of Set 4 | ransang
# Processing Record 25 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 4 | raudeberg
# Processing Record 34 of Set 4 | alekseyevsk
# Processing Record 35 of Set 4 | honiara
# Processing Record 36 of Set 4 | tessalit
# Processing Record 37 of Set 4 | mount gambier
# Processing Record 38 of Set 4 | santiago de cuba
# Processing Record 39 of Set 4 | sola
# Processing Record 40 of Set 4 | verkhnyaya inta
# Processing Record 41 of Set 4 | dragor
# Processing Record 42 of Set 4 | leningradskiy
# Processing Record 43 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 4 | slave lake
# Processing Record 45 of Set 4 | giyon
# Processing Record 46 of Set 4 | boca do acre
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | dingle
# Processing Record 49 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 50 of Set 4 | gniezno
# Processing Record 1 of Set 5 | rocha
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | jabinyanah
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | korla
# Processing Record 6 of Set 5 | corsicana
# Processing Record 7 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 5 | medina
# Processing Record 9 of Set 5 | lola
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | calvinia
# Processing Record 13 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 5 | umiray
# Processing Record 15 of Set 5 | walvis bay
# Processing Record 16 of Set 5 | soe
# Processing Record 17 of Set 5 | champerico
# Processing Record 18 of Set 5 | kijang
# Processing Record 19 of Set 5 | matagami
# Processing Record 20 of Set 5 | broken hill
# Processing Record 21 of Set 5 | yelan
# Processing Record 22 of Set 5 | staryy nadym
# Processing Record 23 of Set 5 | uruzgan
# Processing Record 24 of Set 5 | najran
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | ye
# City not found. Skipping...
# Processing Record 30 of Set 5 | trelew
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | shingu
# Processing Record 35 of Set 5 | san-pedro
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | port augusta
# Processing Record 38 of Set 5 | ulundi
# Processing Record 39 of Set 5 | krasnokamensk
# Processing Record 40 of Set 5 | batemans bay
# Processing Record 41 of Set 5 | urumqi
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | salalah
# Processing Record 44 of Set 5 | yerofey pavlovich
# Processing Record 45 of Set 5 | ndola
# Processing Record 46 of Set 5 | gardan diwal
# City not found. Skipping...
# Processing Record 47 of Set 5 | san andres
# Processing Record 48 of Set 5 | keti bandar
# Processing Record 49 of Set 5 | moura
# Processing Record 50 of Set 5 | dongli
# Processing Record 1 of Set 6 | ankola
# Processing Record 2 of Set 6 | mogadishu
# Processing Record 3 of Set 6 | ewa beach
# Processing Record 4 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 6 | sobolevo
# Processing Record 6 of Set 6 | torbay
# Processing Record 7 of Set 6 | traverse city
# Processing Record 8 of Set 6 | ketchenery
# City not found. Skipping...
# Processing Record 9 of Set 6 | palana
# Processing Record 10 of Set 6 | hay river
# Processing Record 11 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 12 of Set 6 | meulaboh
# Processing Record 13 of Set 6 | svetlaya
# Processing Record 14 of Set 6 | nirasaki
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | areosa
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 6 | cravo norte
# Processing Record 20 of Set 6 | gari
# Processing Record 21 of Set 6 | wenatchee
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | oranjestad
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | bontang
# Processing Record 26 of Set 6 | batsfjord
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | abu samrah
# Processing Record 29 of Set 6 | baisha
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | aripuana
# Processing Record 32 of Set 6 | axim
# Processing Record 33 of Set 6 | funadhoo
# Processing Record 34 of Set 6 | isla vista
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | pokhara
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | pacific grove
# Processing Record 40 of Set 6 | bahia honda
# Processing Record 41 of Set 6 | eureka
# Processing Record 42 of Set 6 | kismayo
# Processing Record 43 of Set 6 | la roche-sur-yon
# Processing Record 44 of Set 6 | afua
# Processing Record 45 of Set 6 | collie
# Processing Record 46 of Set 6 | sinop
# Processing Record 47 of Set 6 | notodden
# Processing Record 48 of Set 6 | hopkinsville
# Processing Record 49 of Set 6 | saint-augustin
# Processing Record 50 of Set 6 | rawson
# Processing Record 1 of Set 7 | shar
# Processing Record 2 of Set 7 | laranjeiras do sul
# Processing Record 3 of Set 7 | ugoofaaru
# Processing Record 4 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 7 | byron bay
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | dicabisagan
# Processing Record 8 of Set 7 | cascavel
# Processing Record 9 of Set 7 | asau
# Processing Record 10 of Set 7 | boa vista
# Processing Record 11 of Set 7 | khandyga
# Processing Record 12 of Set 7 | itarema
# Processing Record 13 of Set 7 | udimskiy
# Processing Record 14 of Set 7 | fecamp
# Processing Record 15 of Set 7 | kula
# Processing Record 16 of Set 7 | simao
# Processing Record 17 of Set 7 | rota
# Processing Record 18 of Set 7 | labuhan
# Processing Record 19 of Set 7 | ous
# Processing Record 20 of Set 7 | thayetmyo
# Processing Record 21 of Set 7 | dongsheng
# Processing Record 22 of Set 7 | ukiah
# Processing Record 23 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 7 | port macquarie
# Processing Record 25 of Set 7 | henties bay
# Processing Record 26 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 7 | safford
# Processing Record 28 of Set 7 | inirida
# Processing Record 29 of Set 7 | hailey
# Processing Record 30 of Set 7 | chilca
# Processing Record 31 of Set 7 | hambantota
# Processing Record 32 of Set 7 | bethel
# Processing Record 33 of Set 7 | yaan
# Processing Record 34 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | uzumlu
# City not found. Skipping...
# Processing Record 38 of Set 7 | angoche
# Processing Record 39 of Set 7 | beyneu
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | tabou
# Processing Record 42 of Set 7 | padang
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | aquiraz
# Processing Record 45 of Set 7 | ust-kulom
# Processing Record 46 of Set 7 | qui nhon
# Processing Record 47 of Set 7 | tabas
# Processing Record 48 of Set 7 | puerto baquerizo moreno
# Processing Record 49 of Set 7 | ozernovskiy
# Processing Record 50 of Set 7 | kantunilkin
# Processing Record 1 of Set 8 | general roca
# Processing Record 2 of Set 8 | deputatskiy
# Processing Record 3 of Set 8 | manokwari
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | gat
# Processing Record 6 of Set 8 | praia da vitoria
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | jatiroto
# Processing Record 10 of Set 8 | kenai
# Processing Record 11 of Set 8 | oil city
# Processing Record 12 of Set 8 | requena
# Processing Record 13 of Set 8 | monroe
# Processing Record 14 of Set 8 | pangnirtung
# Processing Record 15 of Set 8 | ratnagiri
# Processing Record 16 of Set 8 | petrokamenskoye
# Processing Record 17 of Set 8 | petrila
# Processing Record 18 of Set 8 | coolum beach
# Processing Record 19 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 8 | narsaq
# Processing Record 21 of Set 8 | mersing
# Processing Record 22 of Set 8 | pevek
# Processing Record 23 of Set 8 | dukat
# Processing Record 24 of Set 8 | gra liyia
# Processing Record 25 of Set 8 | bartica
# Processing Record 26 of Set 8 | aykhal
# Processing Record 27 of Set 8 | bilibino
# Processing Record 28 of Set 8 | cuitareo
# Processing Record 29 of Set 8 | matiri
# Processing Record 30 of Set 8 | konotop
# Processing Record 31 of Set 8 | veshenskaya
# Processing Record 32 of Set 8 | victoria
# Processing Record 33 of Set 8 | muisne
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | aktau
# Processing Record 36 of Set 8 | kristiansund
# Processing Record 37 of Set 8 | cossato
# Processing Record 38 of Set 8 | rafai
# Processing Record 39 of Set 8 | makakilo city
# Processing Record 40 of Set 8 | diffa
# Processing Record 41 of Set 8 | asarganj
# Processing Record 42 of Set 8 | miramar
# Processing Record 43 of Set 8 | french harbor
# Processing Record 44 of Set 8 | tenenkou
# Processing Record 45 of Set 8 | blind river
# Processing Record 46 of Set 8 | shu
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 49 of Set 8 | ribas do rio pardo
# Processing Record 50 of Set 8 | zvishavane
# Processing Record 1 of Set 9 | olafsvik
# Processing Record 2 of Set 9 | lyngseidet
# Processing Record 3 of Set 9 | kiama
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | south venice
# Processing Record 6 of Set 9 | kaitangata
# Processing Record 7 of Set 9 | hastings
# Processing Record 8 of Set 9 | fernie
# Processing Record 9 of Set 9 | krasnyy yar
# Processing Record 10 of Set 9 | mayumba
# Processing Record 11 of Set 9 | san cristobal
# Processing Record 12 of Set 9 | nador
# Processing Record 13 of Set 9 | bantou
# Processing Record 14 of Set 9 | makat
# Processing Record 15 of Set 9 | kirakira
# Processing Record 16 of Set 9 | berdigestyakh
# Processing Record 17 of Set 9 | toulepleu
# City not found. Skipping...
# Processing Record 18 of Set 9 | yuncheng
# Processing Record 19 of Set 9 | laguna
# Processing Record 20 of Set 9 | manaure
# Processing Record 21 of Set 9 | weifang
# Processing Record 22 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 23 of Set 9 | namibe
# Processing Record 24 of Set 9 | sitka
# Processing Record 25 of Set 9 | raduzhnyy
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | motygino
# Processing Record 29 of Set 9 | launceston
# Processing Record 30 of Set 9 | bordighera
# Processing Record 31 of Set 9 | chuy
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | agvali
# Processing Record 34 of Set 9 | comodoro rivadavia
# Processing Record 35 of Set 9 | arak
# Processing Record 36 of Set 9 | lovington
# Processing Record 37 of Set 9 | muli
# Processing Record 38 of Set 9 | coahuayana
# Processing Record 39 of Set 9 | quelimane
# Processing Record 40 of Set 9 | beisfjord
# Processing Record 41 of Set 9 | arawa
# Processing Record 42 of Set 9 | bucerias
# Processing Record 43 of Set 9 | yantongshan
# Processing Record 44 of Set 9 | mirnyy
# Processing Record 45 of Set 9 | svetlogorsk
# Processing Record 46 of Set 9 | charters towers
# Processing Record 47 of Set 9 | vilhena
# Processing Record 48 of Set 9 | san jose
# Processing Record 49 of Set 9 | bend
# Processing Record 50 of Set 9 | west chester
# Processing Record 1 of Set 10 | nicoya
# Processing Record 2 of Set 10 | bara
# Processing Record 3 of Set 10 | yenagoa
# Processing Record 4 of Set 10 | cambridge
# Processing Record 5 of Set 10 | luau
# Processing Record 6 of Set 10 | shache
# Processing Record 7 of Set 10 | kutum
# Processing Record 8 of Set 10 | dhone
# Processing Record 9 of Set 10 | maragogi
# Processing Record 10 of Set 10 | sikea
# City not found. Skipping...
# Processing Record 11 of Set 10 | black river
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | antofagasta
# Processing Record 14 of Set 10 | puerto del rosario
# Processing Record 15 of Set 10 | andenes
# Processing Record 16 of Set 10 | ewo
# Processing Record 17 of Set 10 | sotnikovo
# Processing Record 18 of Set 10 | kamenka
# Processing Record 19 of Set 10 | mehran
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | normandin
# Processing Record 22 of Set 10 | maple creek
# Processing Record 23 of Set 10 | caxito
# Processing Record 24 of Set 10 | huarmey
# Processing Record 25 of Set 10 | bubaque
# Processing Record 26 of Set 10 | mizdah
# Processing Record 27 of Set 10 | lieksa
# Processing Record 28 of Set 10 | komsomolskiy
# Processing Record 29 of Set 10 | shiyan
# Processing Record 30 of Set 10 | serenje
# Processing Record 31 of Set 10 | alma
# Processing Record 32 of Set 10 | moshenskoye
# Processing Record 33 of Set 10 | asaka
# Processing Record 34 of Set 10 | noumea
# Processing Record 35 of Set 10 | atlantis
# Processing Record 36 of Set 10 | dahra
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | lajas
# Processing Record 39 of Set 10 | atambua
# Processing Record 40 of Set 10 | chumikan
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | rognan
# Processing Record 43 of Set 10 | canoinhas
# Processing Record 44 of Set 10 | fraga
# Processing Record 45 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 10 | parabel
# Processing Record 47 of Set 10 | lindi
# Processing Record 48 of Set 10 | lamu
# Processing Record 49 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 50 of Set 10 | somerset west
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | kerema
# Processing Record 3 of Set 11 | baghdad
# Processing Record 4 of Set 11 | imbituba
# Processing Record 5 of Set 11 | mana
# Processing Record 6 of Set 11 | harper
# Processing Record 7 of Set 11 | zhanakorgan
# Processing Record 8 of Set 11 | zambezi
# Processing Record 9 of Set 11 | lasa
# Processing Record 10 of Set 11 | salamiyah
# Processing Record 11 of Set 11 | westport
# Processing Record 12 of Set 11 | meilu
# City not found. Skipping...
# Processing Record 13 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 14 of Set 11 | clarence town
# Processing Record 15 of Set 11 | teya
# Processing Record 16 of Set 11 | catazaja
# Processing Record 17 of Set 11 | peleduy
# Processing Record 18 of Set 11 | geilo
# Processing Record 19 of Set 11 | linhares
# Processing Record 20 of Set 11 | zuwarah
# Processing Record 21 of Set 11 | krasnoselkup
# Processing Record 22 of Set 11 | puerto escondido
# Processing Record 23 of Set 11 | wladyslawowo
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | hervey bay
# Processing Record 26 of Set 11 | tokmak
# Processing Record 27 of Set 11 | mamlyutka
# Processing Record 28 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 29 of Set 11 | baykit
# Processing Record 30 of Set 11 | chateauroux
# Processing Record 31 of Set 11 | yingcheng
# Processing Record 32 of Set 11 | aketi
# Processing Record 33 of Set 11 | mesen
# Processing Record 34 of Set 11 | chaman
# Processing Record 35 of Set 11 | aswan
# Processing Record 36 of Set 11 | havoysund
# Processing Record 37 of Set 11 | aleksandrov gay
# Processing Record 38 of Set 11 | bhindar
# Processing Record 39 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 11 | okhotsk
# Processing Record 41 of Set 11 | lorengau
# Processing Record 42 of Set 11 | miquelon
# Processing Record 43 of Set 11 | gazimurskiy zavod
# Processing Record 44 of Set 11 | canto do buriti
# Processing Record 45 of Set 11 | ferkessedougou
# Processing Record 46 of Set 11 | jacareacanga
# Processing Record 47 of Set 11 | valley city
# Processing Record 48 of Set 11 | mantua
# Processing Record 49 of Set 11 | singapore
# Processing Record 50 of Set 11 | fare
# Processing Record 1 of Set 12 | bundaberg
# Processing Record 2 of Set 12 | bongandanga
# Processing Record 3 of Set 12 | agropoli
# Processing Record 4 of Set 12 | port blair
# Processing Record 5 of Set 12 | umm kaddadah
# Processing Record 6 of Set 12 | changji
# Processing Record 7 of Set 12 | paka
# Processing Record 8 of Set 12 | beloha
# Processing Record 9 of Set 12 | cachoeira do sul
# Processing Record 10 of Set 12 | vila
# Processing Record 11 of Set 12 | san angelo
# Processing Record 12 of Set 12 | deder
# Processing Record 13 of Set 12 | kudat
# Processing Record 14 of Set 12 | bystryy istok
# Processing Record 15 of Set 12 | vestmannaeyjar
# Processing Record 16 of Set 12 | micheweni
# Processing Record 17 of Set 12 | moerai
# Processing Record 18 of Set 12 | two hills
# Processing Record 19 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 12 | ouadda
# Processing Record 21 of Set 12 | vilyuysk
# Processing Record 22 of Set 12 | soyo
# Processing Record 23 of Set 12 | san lorenzo
# Processing Record 24 of Set 12 | skibbereen
# Processing Record 25 of Set 12 | payson
# Processing Record 26 of Set 12 | bud
# Processing Record 27 of Set 12 | phalombe
# Processing Record 28 of Set 12 | garissa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 526

# %%
city_data
# Out:
# [{'City': 'Sokoto',
#   'Lat': 13.0609,
#   'Lng': 5.239,
#   'Max Temp': 79.48,
#   'Humidity': 15,
#   'Cloudiness': 5,
#   'Wind Speed': 1.19,
#   'Country': 'NG',
#   'Date': '2021-03-15 07:27:09'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 69.98,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.44,
#   'Country': 'CV',
#   'Date': '2021-03-15 07:27:09'},
#  {'City': 'Wajir',
#   'Lat': 1.7471,
#   'Lng': 40.0573,
#   'Max Temp': 82.4,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'KE',
#   'Date': '2021-03-15 07:27:09'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 95,
#   'Humidity': 20,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:26:45'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 19,
#   'Humidity': 33,
#   'Cloudiness': 35,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 80.08,
#   'Humidity': 77,
#   'Cloudiness': 81,
#   'Wind Speed': 7.4,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.8,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AR',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Menongue',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 69.17,
#   'Humidity': 83,
#   'Cloudiness': 39,
#   'Wind Speed': 3,
#   'Country': 'AO',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 60.01,
#   'Humidity': 48,
#   'Cloudiness': 4,
#   'Wind Speed': 1.01,
#   'Country': 'MX',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 68.4,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.36,
#   'Country': 'TL',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 82,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'ES',
#   'Date': '2021-03-15 07:27:10'},
#  {'City': 'Pinega',
#   'Lat': 64.7001,
#   'Lng': 43.3936,
#   'Max Temp': 27.66,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 5.44,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 64.4,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.65,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 11.34,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 51.8,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -22.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:11'},
#  {'City': 'Oda',
#   'Lat': 35.1833,
#   'Lng': 132.5,
#   'Max Temp': 60.8,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'JP',
#   'Date': '2021-03-15 07:22:39'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -7.98,
#   'Humidity': 64,
#   'Cloudiness': 71,
#   'Wind Speed': 6.11,
#   'Country': 'GL',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -15.83,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 63.19,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -5.8,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 24.16,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'RE',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Moranbah',
#   'Lat': -22.0016,
#   'Lng': 148.0466,
#   'Max Temp': 88.84,
#   'Humidity': 41,
#   'Cloudiness': 97,
#   'Wind Speed': 9.71,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Merauke',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 84.04,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 7.99,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 68.56,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 7.67,
#   'Country': 'MR',
#   'Date': '2021-03-15 07:27:12'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -14.8,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 19.02,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 79.83,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.11,
#   'Country': 'KI',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 83.39,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.11,
#   'Country': 'IN',
#   'Date': '2021-03-15 07:25:55'},
#  {'City': 'Tsaratanana',
#   'Lat': -16.7833,
#   'Lng': 47.65,
#   'Max Temp': 81.45,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 8.63,
#   'Country': 'MG',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Quesnel',
#   'Lat': 52.9999,
#   'Lng': -122.5029,
#   'Max Temp': 26.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.53,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 57.99,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'NZ',
#   'Date': '2021-03-15 07:23:53'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 69.01,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:24:22'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 10.4,
#   'Humidity': 67,
#   'Cloudiness': 98,
#   'Wind Speed': 9.22,
#   'Country': 'GL',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 71.67,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 4.72,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Neropolis',
#   'Lat': -16.4064,
#   'Lng': -49.2186,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:13'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55,
#   'Humidity': 73,
#   'Cloudiness': 51,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 82.65,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 0.76,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 83.71,
#   'Humidity': 71,
#   'Cloudiness': 73,
#   'Wind Speed': 2.66,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 71.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 46.67,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Kigorobya',
#   'Lat': 1.6162,
#   'Lng': 31.3089,
#   'Max Temp': 80.98,
#   'Humidity': 44,
#   'Cloudiness': 61,
#   'Wind Speed': 8.28,
#   'Country': 'UG',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 35.89,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Country': 'IS',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 75.2,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'SA',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:14'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'PE',
#   'Date': '2021-03-15 07:27:15'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 54.9,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 14.12,
#   'Country': 'MX',
#   'Date': '2021-03-15 07:27:15'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 26.6,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:15'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': -2.2,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'SJ',
#   'Date': '2021-03-15 07:27:15'},
#  {'City': 'Ibotirama',
#   'Lat': -12.1853,
#   'Lng': -43.2206,
#   'Max Temp': 70.34,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:16'},
#  {'City': 'Terney',
#   'Lat': 45.0503,
#   'Lng': 136.6092,
#   'Max Temp': 42.6,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.11,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:16'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 19.99,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 12.53,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:16'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 63,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:16'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 72.55,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.25,
#   'Country': 'MX',
#   'Date': '2021-03-15 07:23:39'},
#  {'City': 'Zemio',
#   'Lat': 5.0314,
#   'Lng': 25.1361,
#   'Max Temp': 77.27,
#   'Humidity': 74,
#   'Cloudiness': 95,
#   'Wind Speed': 1.95,
#   'Country': 'CF',
#   'Date': '2021-03-15 07:27:17'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TO',
#   'Date': '2021-03-15 07:27:17'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 26.6,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:17'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 19,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:23:50'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 69.01,
#   'Humidity': 45,
#   'Cloudiness': 3,
#   'Wind Speed': 3.38,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:17'},
#  {'City': 'Sivaki',
#   'Lat': 52.6333,
#   'Lng': 126.75,
#   'Max Temp': 26.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 17.11,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 84.54,
#   'Humidity': 69,
#   'Cloudiness': 3,
#   'Wind Speed': 6.49,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 63,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Powell River',
#   'Lat': 49.8496,
#   'Lng': -124.5361,
#   'Max Temp': 37.4,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 80.01,
#   'Humidity': 5,
#   'Cloudiness': 2,
#   'Wind Speed': 4.83,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 91.4,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'MY',
#   'Date': '2021-03-15 07:26:26'},
#  {'City': 'Adeje',
#   'Lat': 28.1227,
#   'Lng': -16.726,
#   'Max Temp': 61,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'ES',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 87.21,
#   'Humidity': 62,
#   'Cloudiness': 33,
#   'Wind Speed': 5.08,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -5.8,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 82.24,
#   'Humidity': 67,
#   'Cloudiness': 16,
#   'Wind Speed': 3.15,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Magdagachi',
#   'Lat': 53.45,
#   'Lng': 125.8,
#   'Max Temp': 19.06,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 18.16,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 36.1,
#   'Humidity': 90,
#   'Cloudiness': 43,
#   'Wind Speed': 10.29,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:18'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 26.6,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 44.87,
#   'Country': 'GL',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 3.2,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:23:58'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 59,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 88.84,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Country': 'LK',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 25.09,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'MN',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Marathon',
#   'Lat': 44.9,
#   'Lng': -89.7668,
#   'Max Temp': 26.6,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.16,
#   'Country': 'GF',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 17.78,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 13.51,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 80.19,
#   'Humidity': 18,
#   'Cloudiness': 92,
#   'Wind Speed': 3.98,
#   'Country': 'YE',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 83.3,
#   'Humidity': 68,
#   'Cloudiness': 37,
#   'Wind Speed': 7.49,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 84.65,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 6.22,
#   'Country': 'MV',
#   'Date': '2021-03-15 07:27:19'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 85.39,
#   'Humidity': 65,
#   'Cloudiness': 66,
#   'Wind Speed': 6.35,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:22:46'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 81.97,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Country': 'SB',
#   'Date': '2021-03-15 07:27:20'},
#  {'City': 'Tahe',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 17.92,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:20'},
#  {'City': 'Mircea Voda',
#   'Lat': 44.2833,
#   'Lng': 28.1667,
#   'Max Temp': 54,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'RO',
#   'Date': '2021-03-15 07:27:20'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.81,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 12.95,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:27:20'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 73.99,
#   'Humidity': 97,
#   'Cloudiness': 33,
#   'Wind Speed': 5.08,
#   'Country': 'EC',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 42.8,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'San Joaquin',
#   'Lat': 37.9333,
#   'Lng': -121.3011,
#   'Max Temp': 48.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -16.6,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 45,
#   'Humidity': 84,
#   'Cloudiness': 52,
#   'Wind Speed': 5.99,
#   'Country': 'GB',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 70.48,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 15.86,
#   'Country': 'NE',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Shubarkuduk',
#   'Lat': 49.1447,
#   'Lng': 56.4872,
#   'Max Temp': 11.46,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Country': 'KZ',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Bay Roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 21.99,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:21'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 55,
#   'Humidity': 73,
#   'Cloudiness': 10,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 69.22,
#   'Humidity': 98,
#   'Cloudiness': 52,
#   'Wind Speed': 1.83,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:25:14'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.49,
#   'Humidity': 69,
#   'Cloudiness': 3,
#   'Wind Speed': 10.25,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'At-Bashi',
#   'Lat': 41.1702,
#   'Lng': 75.8106,
#   'Max Temp': 28.13,
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 2.17,
#   'Country': 'KG',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Foster',
#   'Lat': 41.8537,
#   'Lng': -71.7581,
#   'Max Temp': 21,
#   'Humidity': 42,
#   'Cloudiness': 98,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 84.13,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'SB',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 65.35,
#   'Humidity': 88,
#   'Cloudiness': 70,
#   'Wind Speed': 1.52,
#   'Country': 'NZ',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Bima',
#   'Lat': -8.4667,
#   'Lng': 118.7167,
#   'Max Temp': 85.14,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 2.93,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'CK',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:22'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'IS',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 4.01,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 82.22,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 15.37,
#   'Country': 'SO',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Santa Vitoria Do Palmar',
#   'Lat': -33.5189,
#   'Lng': -53.3681,
#   'Max Temp': 62.19,
#   'Humidity': 87,
#   'Cloudiness': 23,
#   'Wind Speed': 3.09,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Taseyevo',
#   'Lat': 57.2169,
#   'Lng': 94.8978,
#   'Max Temp': 22.57,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 39.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Trincomalee',
#   'Lat': 8.5711,
#   'Lng': 81.2335,
#   'Max Temp': 82.69,
#   'Humidity': 66,
#   'Cloudiness': 45,
#   'Wind Speed': 10.98,
#   'Country': 'LK',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 73.69,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 10.25,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:23'},
#  {'City': 'Juruti',
#   'Lat': -2.1522,
#   'Lng': -56.0922,
#   'Max Temp': 73.31,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:24'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 60.01,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:24'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 61.5,
#   'Humidity': 92,
#   'Cloudiness': 2,
#   'Wind Speed': 2.57,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:24'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.91,
#   'Humidity': 94,
#   'Cloudiness': 18,
#   'Wind Speed': 2.21,
#   'Country': 'CL',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'GB',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Jinhua',
#   'Lat': 29.1078,
#   'Lng': 119.6547,
#   'Max Temp': 79.21,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Vychegodskiy',
#   'Lat': 61.247,
#   'Lng': 46.8984,
#   'Max Temp': 30.25,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.77,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.63,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 0,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 0.97,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 1.99,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 30.38,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'GL',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 83.17,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 6.73,
#   'Country': 'OM',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Salta',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.12,
#   'Country': 'AR',
#   'Date': '2021-03-15 07:27:25'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -8.72,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 7.07,
#   'Country': 'GL',
#   'Date': '2021-03-15 07:27:26'},
#  {'City': 'Ust-Maya',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': 18.82,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 15.1,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:26'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 66.2,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'JP',
#   'Date': '2021-03-15 07:25:39'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 37.4,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 13.42,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:27:26'},
#  {'City': 'Ola',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 12.27,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:26'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 76.57,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Country': 'GF',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 89.53,
#   'Humidity': 20,
#   'Cloudiness': 2,
#   'Wind Speed': 7.63,
#   'Country': 'IN',
#   'Date': '2021-03-15 07:22:44'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -19.14,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 66.99,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Wattegama',
#   'Lat': 6.7989,
#   'Lng': 81.4808,
#   'Max Temp': 91.4,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'LK',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'BB',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Vilcun',
#   'Lat': -38.65,
#   'Lng': -72.2333,
#   'Max Temp': 55.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Teguise',
#   'Lat': 29.0605,
#   'Lng': -13.564,
#   'Max Temp': 57.2,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'ES',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 72.81,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22,
#   'Country': 'PE',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'CV',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Pemangkat',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 82.83,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.78,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:27'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:28'},
#  {'City': 'Dreznica',
#   'Lat': 43.5289,
#   'Lng': 17.2819,
#   'Max Temp': 48.2,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'BA',
#   'Date': '2021-03-15 07:27:28'},
#  {'City': 'Oxford',
#   'Lat': 51.7522,
#   'Lng': -1.256,
#   'Max Temp': 45,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'GB',
#   'Date': '2021-03-15 07:27:07'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.3,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:27:28'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 24.49,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.14,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:28'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 30.67,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 11.81,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:29'},
#  {'City': 'Ransang',
#   'Lat': 8.9603,
#   'Lng': 117.5828,
#   'Max Temp': 83.84,
#   'Humidity': 74,
#   'Cloudiness': 71,
#   'Wind Speed': 7.74,
#   'Country': 'PH',
#   'Date': '2021-03-15 07:27:29'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -7.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:29'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 48.99,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 2.15,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:29'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -6.32,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:29'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 77,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:30'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 66,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AR',
#   'Date': '2021-03-15 07:27:30'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 37.99,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:27:30'},
#  {'City': 'Alekseyevsk',
#   'Lat': 57.8406,
#   'Lng': 108.3492,
#   'Max Temp': 17.78,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 13.53,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 80.19,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3.24,
#   'Country': 'SB',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 66.99,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 8.97,
#   'Country': 'ML',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Santiago De Cuba',
#   'Lat': 20.0247,
#   'Lng': -75.8219,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 84.2,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 10.42,
#   'Country': 'VU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Verkhnyaya Inta',
#   'Lat': 65.9811,
#   'Lng': 60.3094,
#   'Max Temp': 22.5,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.84,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Dragor',
#   'Lat': 55.5946,
#   'Lng': 12.6664,
#   'Max Temp': 41,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'DK',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -1.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:31'},
#  {'City': 'Slave Lake',
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp': 23,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 28.77,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Giyon',
#   'Lat': 8.5333,
#   'Lng': 37.9833,
#   'Max Temp': 76.91,
#   'Humidity': 29,
#   'Cloudiness': 69,
#   'Wind Speed': 8.79,
#   'Country': 'ET',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Boca Do Acre',
#   'Lat': -8.7522,
#   'Lng': -67.3978,
#   'Max Temp': 72.81,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 85.93,
#   'Humidity': 70,
#   'Cloudiness': 4,
#   'Wind Speed': 9.66,
#   'Country': 'PH',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Gniezno',
#   'Lat': 52.5348,
#   'Lng': 17.5826,
#   'Max Temp': 37,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Country': 'PL',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 58.1,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 1.72,
#   'Country': 'UY',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'VU',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Jabinyanah',
#   'Lat': 35.035,
#   'Lng': 10.9081,
#   'Max Temp': 57.2,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'TN',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -17.14,
#   'Humidity': 97,
#   'Cloudiness': 4,
#   'Wind Speed': 4.56,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 63.01,
#   'Humidity': 22,
#   'Cloudiness': 63,
#   'Wind Speed': 10.13,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:32'},
#  {'City': 'Corsicana',
#   'Lat': 32.0954,
#   'Lng': -96.4689,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:33'},
#  {'City': 'Medina',
#   'Lat': 24.4686,
#   'Lng': 39.6142,
#   'Max Temp': 82.4,
#   'Humidity': 28,
#   'Cloudiness': 2,
#   'Wind Speed': 3.27,
#   'Country': 'SA',
#   'Date': '2021-03-15 07:27:33'},
#  {'City': 'Lola',
#   'Lat': 7.8,
#   'Lng': -8.5333,
#   'Max Temp': 70,
#   'Humidity': 95,
#   'Cloudiness': 73,
#   'Wind Speed': 1.77,
#   'Country': 'GN',
#   'Date': '2021-03-15 07:27:33'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -5.8,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 1.36,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:33'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99,
#   'Country': 'FO',
#   'Date': '2021-03-15 07:27:33'},
#  {'City': 'Calvinia',
#   'Lat': -31.4707,
#   'Lng': 19.776,
#   'Max Temp': 60.66,
#   'Humidity': 63,
#   'Cloudiness': 16,
#   'Wind Speed': 7,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Umiray',
#   'Lat': 15.2206,
#   'Lng': 121.4111,
#   'Max Temp': 79.25,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Country': 'PH',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 61,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'NA',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Soe',
#   'Lat': -9.8607,
#   'Lng': 124.284,
#   'Max Temp': 74.88,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 66,
#   'Humidity': 92,
#   'Cloudiness': 39,
#   'Wind Speed': 7.07,
#   'Country': 'GT',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Kijang',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 62.6,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'KR',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': -9.4,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 73.4,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Yelan',
#   'Lat': 50.949,
#   'Lng': 43.7378,
#   'Max Temp': 27.73,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 16.33,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:34'},
#  {'City': 'Staryy Nadym',
#   'Lat': 65.6118,
#   'Lng': 72.6842,
#   'Max Temp': 19.65,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind Speed': 11.03,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:35'},
#  {'City': 'Uruzgan',
#   'Lat': 32.8333,
#   'Lng': 66,
#   'Max Temp': 57.2,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'AF',
#   'Date': '2021-03-15 07:27:35'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 73.4,
#   'Humidity': 28,
#   'Cloudiness': 15,
#   'Wind Speed': 4.61,
#   'Country': 'SA',
#   'Date': '2021-03-15 07:27:35'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 55.33,
#   'Humidity': 19,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:35'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 54,
#   'Humidity': 70,
#   'Cloudiness': 25,
#   'Wind Speed': 3,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:27:35'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 80.6,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:36'},
#  {'City': 'Trelew',
#   'Lat': -43.249,
#   'Lng': -65.3051,
#   'Max Temp': 62.31,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 20.6,
#   'Country': 'AR',
#   'Date': '2021-03-15 07:27:36'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': '2021-03-15 07:27:36'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 67.32,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 22.53,
#   'Country': 'NA',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 60.8,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'JP',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'San-Pedro',
#   'Lat': 4.7485,
#   'Lng': -6.6363,
#   'Max Temp': 76.05,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'CI',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 37.99,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 75.99,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Ulundi',
#   'Lat': -28.3352,
#   'Lng': 31.4162,
#   'Max Temp': 76.5,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.39,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Krasnokamensk',
#   'Lat': 50.0979,
#   'Lng': 118.0369,
#   'Max Temp': 18.5,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 28.59,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 66.99,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -13,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 6.29,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 84.2,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'OM',
#   'Date': '2021-03-15 07:27:37'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 13.33,
#   'Humidity': 65,
#   'Cloudiness': 27,
#   'Wind Speed': 16.58,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:38'},
#  {'City': 'Ndola',
#   'Lat': -12.9587,
#   'Lng': 28.6366,
#   'Max Temp': 68.31,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99,
#   'Country': 'ZM',
#   'Date': '2021-03-15 07:27:38'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'CO',
#   'Date': '2021-03-15 07:27:38'},
#  {'City': 'Keti Bandar',
#   'Lat': 24.1447,
#   'Lng': 67.4497,
#   'Max Temp': 85.64,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 17.2,
#   'Country': 'PK',
#   'Date': '2021-03-15 07:27:38'},
#  {'City': 'Moura',
#   'Lat': 38.1401,
#   'Lng': -7.4486,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:27:39'},
#  {'City': 'Dongli',
#   'Lat': 23.5656,
#   'Lng': 116.8194,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 6.71,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:39'},
#  {'City': 'Ankola',
#   'Lat': 14.6667,
#   'Lng': 74.3,
#   'Max Temp': 91.35,
#   'Humidity': 49,
#   'Cloudiness': 10,
#   'Wind Speed': 8.01,
#   'Country': 'IN',
#   'Date': '2021-03-15 07:27:39'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'SO',
#   'Date': '2021-03-15 07:27:39'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 1.3,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:39'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 33.76,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 11.16,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:40'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:40'},
#  {'City': 'Traverse City',
#   'Lat': 44.7631,
#   'Lng': -85.6206,
#   'Max Temp': 24.01,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 4.97,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:40'},
#  {'City': 'Palana',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 5.31,
#   'Humidity': 95,
#   'Cloudiness': 87,
#   'Wind Speed': 6.82,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:40'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 1.4,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:40'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 85.62,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:41'},
#  {'City': 'Svetlaya',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': 40.39,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 9.55,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:41'},
#  {'City': 'Nirasaki',
#   'Lat': 35.7,
#   'Lng': 138.45,
#   'Max Temp': 60.01,
#   'Humidity': 37,
#   'Cloudiness': 2,
#   'Wind Speed': 5.01,
#   'Country': 'JP',
#   'Date': '2021-03-15 07:24:22'},
#  {'City': 'Areosa',
#   'Lat': 41.7178,
#   'Lng': -8.8571,
#   'Max Temp': 51.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:27:41'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 1.4,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:27:41'},
#  {'City': 'Cravo Norte',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 78.1,
#   'Humidity': 72,
#   'Cloudiness': 76,
#   'Wind Speed': 3.71,
#   'Country': 'CO',
#   'Date': '2021-03-15 07:27:42'},
#  {'City': 'Gari',
#   'Lat': 59.4307,
#   'Lng': 62.3497,
#   'Max Temp': 22.84,
#   'Humidity': 86,
#   'Cloudiness': 80,
#   'Wind Speed': 11.77,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:27:42'},
#  {'City': 'Wenatchee',
#   'Lat': 47.4235,
#   'Lng': -120.3103,
#   'Max Temp': 45,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-03-15 07:27:42'},
#  {'City': 'Oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'AW',
#   'Date': '2021-03-15 07:27:42'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.6,
#   'Country': 'NU',
#   'Date': '2021-03-15 07:27:43'},
#  {'City': 'Bontang',
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 86.97,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:27:43'},
#  {'City': 'Batsfjord',
#   'Lat': 70.6345,
#   'Lng': 29.7185,
#   'Max Temp': 30.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:27:43'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 61.29,
#   'Humidity': 33,
#   'Cloudiness': 62,
#   'Wind Speed': 4.18,
#   'Country': 'SY',
#   'Date': '2021-03-15 07:27:43'},
#  {'City': 'Baisha',
#   'Lat': 26.5222,
#   'Lng': 110.9311,
#   'Max Temp': 77.59,
#   'Humidity': 64,
#   'Cloudiness': 59,
#   'Wind Speed': 6.78,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:27:44'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 42.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Date': '2021-03-15 07:25:50'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 71.94,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:27:44'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 77.97,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Country': 'GH',
#   'Date': '2021-03-15 07:27:44'},
#  {'City': 'Funadhoo',
#   'Lat': 6.15,
#   'Lng': 73.2667,
#   'Max Temp': 82.47,
#   'Humidity': 76,
#   'Cloudiness': 13,
#   'Wind Speed': 12.82,
#   'Country': 'MV',
#   'Date': '2021-03-15 07:27:44'},
#  {'City': 'Isla Vista',
#   'Lat': 34.4133,
# ...
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 17.31,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:06'},
#  {'City': 'Lajas',
#   'Lat': 18.05,
#   'Lng': -67.0593,
#   'Max Temp': 72,
#   'Humidity': 92,
#   'Cloudiness': 33,
#   'Wind Speed': 1.01,
#   'Country': 'PR',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 80.83,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 2.68,
#   'Country': 'ID',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Chumikan',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 28.36,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 18.36,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 8.34,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Rognan',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 32,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 3.18,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Canoinhas',
#   'Lat': -26.1772,
#   'Lng': -50.39,
#   'Max Temp': 61.39,
#   'Humidity': 99,
#   'Cloudiness': 26,
#   'Wind Speed': 1.36,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Fraga',
#   'Lat': 41.5229,
#   'Lng': 0.3489,
#   'Max Temp': 39,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'ES',
#   'Date': '2021-03-15 07:28:07'},
#  {'City': 'Parabel',
#   'Lat': 58.6978,
#   'Lng': 81.4825,
#   'Max Temp': 17.96,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:08'},
#  {'City': 'Lindi',
#   'Lat': -10,
#   'Lng': 39.7167,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'TZ',
#   'Date': '2021-03-15 07:28:08'},
#  {'City': 'Lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'KE',
#   'Date': '2021-03-15 07:28:08'},
#  {'City': 'Somerset West',
#   'Lat': -34.084,
#   'Lng': 18.8211,
#   'Max Temp': 63,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'ZA',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Kerema',
#   'Lat': -7.9631,
#   'Lng': 145.7785,
#   'Max Temp': 83.19,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 4.92,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Baghdad',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 71.6,
#   'Humidity': 37,
#   'Cloudiness': 52,
#   'Wind Speed': 6.91,
#   'Country': 'IQ',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 76.12,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'GF',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'LR',
#   'Date': '2021-03-15 07:28:09'},
#  {'City': 'Zhanakorgan',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 26.1,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63,
#   'Country': 'KZ',
#   'Date': '2021-03-15 07:28:10'},
#  {'City': 'Zambezi',
#   'Lat': -13.5432,
#   'Lng': 23.1047,
#   'Max Temp': 70.79,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 4.7,
#   'Country': 'ZM',
#   'Date': '2021-03-15 07:28:10'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 39,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'IT',
#   'Date': '2021-03-15 07:24:16'},
#  {'City': 'Salamiyah',
#   'Lat': 35.0113,
#   'Lng': 37.0532,
#   'Max Temp': 60.78,
#   'Humidity': 33,
#   'Cloudiness': 87,
#   'Wind Speed': 2.55,
#   'Country': 'SY',
#   'Date': '2021-03-15 07:28:10'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 27,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2021-03-15 07:28:10'},
#  {'City': 'Clarence Town',
#   'Lat': -32.5833,
#   'Lng': 151.7833,
#   'Max Temp': 71.01,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:28:11'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 18.09,
#   'Humidity': 86,
#   'Cloudiness': 93,
#   'Wind Speed': 11.7,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:11'},
#  {'City': 'Catazaja',
#   'Lat': 17.725,
#   'Lng': -92.0167,
#   'Max Temp': 74.89,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 10.09,
#   'Country': 'MX',
#   'Date': '2021-03-15 07:28:11'},
#  {'City': 'Peleduy',
#   'Lat': 59.6289,
#   'Lng': 112.7406,
#   'Max Temp': 17.87,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 15.75,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:11'},
#  {'City': 'Geilo',
#   'Lat': 60.5333,
#   'Lng': 8.2076,
#   'Max Temp': 15.01,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.82,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:28:11'},
#  {'City': 'Linhares',
#   'Lat': -19.3911,
#   'Lng': -40.0722,
#   'Max Temp': 69.71,
#   'Humidity': 97,
#   'Cloudiness': 1,
#   'Wind Speed': 2.53,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Zuwarah',
#   'Lat': 32.9312,
#   'Lng': 12.082,
#   'Max Temp': 60.15,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 12.06,
#   'Country': 'LY',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 14.43,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 8.63,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 75.61,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.53,
#   'Country': 'MX',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Wladyslawowo',
#   'Lat': 54.7909,
#   'Lng': 18.4009,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'PL',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 81,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Tokmak',
#   'Lat': 47.2514,
#   'Lng': 35.7058,
#   'Max Temp': 41.86,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 12.62,
#   'Country': 'UA',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Mamlyutka',
#   'Lat': 54.9375,
#   'Lng': 68.5394,
#   'Max Temp': 8.6,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'KZ',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 18.72,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:12'},
#  {'City': 'Chateauroux',
#   'Lat': 46.8167,
#   'Lng': 1.7,
#   'Max Temp': 44.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'FR',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Yingcheng',
#   'Lat': 30.95,
#   'Lng': 113.55,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Aketi',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 74.53,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.38,
#   'Country': 'CD',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Mesen',
#   'Lat': 50.7658,
#   'Lng': 2.8976,
#   'Max Temp': 44.01,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 3,
#   'Country': 'BE',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Chaman',
#   'Lat': 30.9236,
#   'Lng': 66.4512,
#   'Max Temp': 69.08,
#   'Humidity': 21,
#   'Cloudiness': 61,
#   'Wind Speed': 8.66,
#   'Country': 'PK',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 78.55,
#   'Humidity': 24,
#   'Cloudiness': 92,
#   'Wind Speed': 3.06,
#   'Country': 'EG',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 30.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Country': 'NO',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Aleksandrov Gay',
#   'Lat': 50.147,
#   'Lng': 48.5704,
#   'Max Temp': 23.27,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.36,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Bhindar',
#   'Lat': 24.5,
#   'Lng': 74.1833,
#   'Max Temp': 89.6,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2021-03-15 07:28:13'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 15.66,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 84.24,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Country': 'PG',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Miquelon',
#   'Lat': 47.0975,
#   'Lng': -56.3814,
#   'Max Temp': 24.42,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 16.78,
#   'Country': 'PM',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Gazimurskiy Zavod',
#   'Lat': 51.5461,
#   'Lng': 118.3266,
#   'Max Temp': 18.97,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 18.57,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Canto Do Buriti',
#   'Lat': -8.11,
#   'Lng': -42.9444,
#   'Max Temp': 69.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Ferkessedougou',
#   'Lat': 9.6,
#   'Lng': -5.2,
#   'Max Temp': 75.88,
#   'Humidity': 37,
#   'Cloudiness': 98,
#   'Wind Speed': 4.27,
#   'Country': 'CI',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 70.52,
#   'Humidity': 98,
#   'Cloudiness': 27,
#   'Wind Speed': 0.85,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:14'},
#  {'City': 'Valley City',
#   'Lat': 46.9233,
#   'Lng': -98.0032,
#   'Max Temp': 30.2,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Mantua',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 44.01,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 5.01,
#   'Country': 'IT',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Singapore',
#   'Lat': 1.2897,
#   'Lng': 103.8501,
#   'Max Temp': 82.4,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'SG',
#   'Date': '2021-03-15 07:27:36'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 82.85,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 15.05,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 82.99,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Bongandanga',
#   'Lat': 1.5,
#   'Lng': 21.05,
#   'Max Temp': 73.9,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Country': 'CD',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Agropoli',
#   'Lat': 40.3469,
#   'Lng': 14.9966,
#   'Max Temp': 52,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'IT',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 86.11,
#   'Humidity': 63,
#   'Cloudiness': 56,
#   'Wind Speed': 13.58,
#   'Country': 'IN',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Umm Kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 86.54,
#   'Humidity': 7,
#   'Cloudiness': 100,
#   'Wind Speed': 14.7,
#   'Country': 'SD',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Changji',
#   'Lat': 44.0167,
#   'Lng': 87.3167,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Paka',
#   'Lat': 4.6374,
#   'Lng': 103.4368,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MY',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 84.49,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 10.27,
#   'Country': 'MG',
#   'Date': '2021-03-15 07:28:15'},
#  {'City': 'Cachoeira Do Sul',
#   'Lat': -30.0392,
#   'Lng': -52.8939,
#   'Max Temp': 61.97,
#   'Humidity': 94,
#   'Cloudiness': 14,
#   'Wind Speed': 3.78,
#   'Country': 'BR',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Cloudiness': 36,
#   'Wind Speed': 3.8,
#   'Country': 'PT',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'San Angelo',
#   'Lat': 31.4638,
#   'Lng': -100.437,
#   'Max Temp': 55,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Deder',
#   'Lat': 9.3167,
#   'Lng': 41.45,
#   'Max Temp': 70.05,
#   'Humidity': 40,
#   'Cloudiness': 56,
#   'Wind Speed': 8.93,
#   'Country': 'ET',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Kudat',
#   'Lat': 6.8837,
#   'Lng': 116.8477,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'MY',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Bystryy Istok',
#   'Lat': 52.371,
#   'Lng': 84.3873,
#   'Max Temp': 15.17,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 9.24,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 42.28,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 24.92,
#   'Country': 'IS',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Micheweni',
#   'Lat': -4.9667,
#   'Lng': 39.8333,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'TZ',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Moerai',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp': 79.86,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 18.59,
#   'Country': 'PF',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Two Hills',
#   'Lat': 53.7169,
#   'Lng': -111.7518,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2021-03-15 07:28:16'},
#  {'City': 'Ouadda',
#   'Lat': 8.0777,
#   'Lng': 22.4007,
#   'Max Temp': 79.27,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Country': 'CF',
#   'Date': '2021-03-15 07:28:17'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': -0.33,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 9.78,
#   'Country': 'RU',
#   'Date': '2021-03-15 07:28:17'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'AO',
#   'Date': '2021-03-15 07:28:17'},
#  {'City': 'San Lorenzo',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'PY',
#   'Date': '2021-03-15 07:28:17'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'IE',
#   'Date': '2021-03-15 07:28:17'},
#  {'City': 'Payson',
#   'Lat': 40.0444,
#   'Lng': -111.7321,
#   'Max Temp': 39.99,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 5.59,
#   'Country': 'US',
#   'Date': '2021-03-15 07:28:18'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 39.99,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 15.21,
#   'Country': 'US',
#   'Date': '2021-03-15 07:28:18'},
#  {'City': 'Phalombe',
#   'Lat': -15.8064,
#   'Lng': 35.6507,
#   'Max Temp': 72.75,
#   'Humidity': 82,
#   'Cloudiness': 52,
#   'Wind Speed': 1.74,
#   'Country': 'MW',
#   'Date': '2021-03-15 07:28:18'},
#  {'City': 'Garissa',
#   'Lat': -0.4536,
#   'Lng': 39.6401,
#   'Max Temp': 81.86,
#   'Humidity': 57,
#   'Cloudiness': 97,
#   'Wind Speed': 7.07,
#   'Country': 'KE',
#   'Date': '2021-03-15 07:28:18'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sokoto  13.0609    5.2390     79.48        15           5
# 1      Sao Filipe  14.8961  -24.4956     69.98        73           0
# 2           Wajir   1.7471   40.0573     82.40        57          75
# 3       Geraldton -28.7667  114.6000     95.00        20          40
# 4          Albany  42.6001  -73.9662     19.00        33          35
# 5         Rikitea -23.1203 -134.9692     80.08        77          81
# 6         Ushuaia -54.8000  -68.3000     51.80        66          75
# 7        Menongue -14.6585   17.6910     69.17        83          39
# 8  Cabo San Lucas  22.8909 -109.9124     60.01        48           4
# 9       Kununurra -15.7667  128.7333     86.00        74          75
#
#    Wind Speed Country                 Date
# 0        1.19      NG  2021-03-15 07:27:09
# 1        6.44      CV  2021-03-15 07:27:09
# 2        5.75      KE  2021-03-15 07:27:09
# 3        8.05      AU  2021-03-15 07:26:45
# 4        5.01      US  2021-03-15 07:27:10
# 5        7.40      PF  2021-03-15 07:27:10
# 6        6.91      AR  2021-03-15 07:27:10
# 7        3.00      AO  2021-03-15 07:27:10
# 8        1.01      MX  2021-03-15 07:27:10
# 9        8.05      AU  2021-03-15 07:27:10

# %%
new_column_order = ["City", "Country", "Date", "Date","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#          City Country                 Date                 Date  \
# 0      Sokoto      NG  2021-03-15 07:27:09  2021-03-15 07:27:09
# 1  Sao Filipe      CV  2021-03-15 07:27:09  2021-03-15 07:27:09
# 2       Wajir      KE  2021-03-15 07:27:09  2021-03-15 07:27:09
# 3   Geraldton      AU  2021-03-15 07:26:45  2021-03-15 07:26:45
# 4      Albany      US  2021-03-15 07:27:10  2021-03-15 07:27:10
#
#                   Date                 Date      Lat       Lng  Max Temp  \
# 0  2021-03-15 07:27:09  2021-03-15 07:27:09  13.0609    5.2390     79.48
# 1  2021-03-15 07:27:09  2021-03-15 07:27:09  14.8961  -24.4956     69.98
# 2  2021-03-15 07:27:09  2021-03-15 07:27:09   1.7471   40.0573     82.40
# 3  2021-03-15 07:26:45  2021-03-15 07:26:45 -28.7667  114.6000     95.00
# 4  2021-03-15 07:27:10  2021-03-15 07:27:10  42.6001  -73.9662     19.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        15           5        1.19
# 1        73           0        6.44
# 2        57          75        5.75
# 3        20          40        8.05
# 4        33          35        5.01

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
